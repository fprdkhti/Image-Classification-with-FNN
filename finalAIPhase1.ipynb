# %%
import numpy as np
import random, os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import pandas as pd

# %% [markdown]
# فاز یک:

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7c7bbbd0-9741-4d51-ad6e-19d99337b87e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c7bbbd0-9741-4d51-ad6e-19d99337b87e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cifar_dataset.zip to cifar_dataset.zip

# %%
# !unzip cifar_dataset.zip -d /content/des
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/des/data/10102.png
#   inflating: /content/des/data/10159.png
#   inflating: /content/des/data/10187.png
#   inflating: /content/des/data/10190.png
#   inflating: /content/des/data/102.png
#   inflating: /content/des/data/10245.png
#   inflating: /content/des/data/10256.png
#   inflating: /content/des/data/1031.png
#   inflating: /content/des/data/10330.png
#   inflating: /content/des/data/10348.png
#   inflating: /content/des/data/10415.png
#   inflating: /content/des/data/1042.png
#   inflating: /content/des/data/10423.png
#   inflating: /content/des/data/10463.png
#   inflating: /content/des/data/10502.png
#   inflating: /content/des/data/10519.png
#   inflating: /content/des/data/10548.png
#   inflating: /content/des/data/1058.png
#   inflating: /content/des/data/10635.png
#   inflating: /content/des/data/10686.png
#   inflating: /content/des/data/10723.png
#   inflating: /content/des/data/10906.png
#   inflating: /content/des/data/10943.png
#   inflating: /content/des/data/11020.png
#   inflating: /content/des/data/11047.png
#   inflating: /content/des/data/11080.png
#   inflating: /content/des/data/11168.png
#   inflating: /content/des/data/11196.png
#   inflating: /content/des/data/1126.png
#   inflating: /content/des/data/1128.png
#   inflating: /content/des/data/11324.png
#   inflating: /content/des/data/11330.png
#   inflating: /content/des/data/11358.png
#   inflating: /content/des/data/1136.png
#   inflating: /content/des/data/11435.png
#   inflating: /content/des/data/11450.png
#   inflating: /content/des/data/11499.png
#   inflating: /content/des/data/11554.png
#   inflating: /content/des/data/11609.png
#   inflating: /content/des/data/11657.png
#   inflating: /content/des/data/11750.png
#   inflating: /content/des/data/11841.png
#   inflating: /content/des/data/11856.png
#   inflating: /content/des/data/11859.png
#   inflating: /content/des/data/12008.png
#   inflating: /content/des/data/12037.png
#   inflating: /content/des/data/12212.png
#   inflating: /content/des/data/12244.png
#   inflating: /content/des/data/12437.png
#   inflating: /content/des/data/12440.png
#   inflating: /content/des/data/12501.png
#   inflating: /content/des/data/12674.png
#   inflating: /content/des/data/12745.png
#   inflating: /content/des/data/1276.png
#   inflating: /content/des/data/12764.png
#   inflating: /content/des/data/12784.png
#   inflating: /content/des/data/12846.png
#   inflating: /content/des/data/12902.png
#   inflating: /content/des/data/12942.png
#   inflating: /content/des/data/12966.png
#   inflating: /content/des/data/13065.png
#   inflating: /content/des/data/13133.png
#   inflating: /content/des/data/13148.png
#   inflating: /content/des/data/13172.png
#   inflating: /content/des/data/13186.png
#   inflating: /content/des/data/13194.png
#   inflating: /content/des/data/13331.png
#   inflating: /content/des/data/13354.png
#   inflating: /content/des/data/13431.png
#   inflating: /content/des/data/1346.png
#   inflating: /content/des/data/13548.png
#   inflating: /content/des/data/13585.png
#   inflating: /content/des/data/13602.png
#   inflating: /content/des/data/13697.png
#   inflating: /content/des/data/1370.png
#   inflating: /content/des/data/13719.png
#   inflating: /content/des/data/13751.png
#   inflating: /content/des/data/13794.png
#   inflating: /content/des/data/13914.png
#   inflating: /content/des/data/13929.png
#   inflating: /content/des/data/13932.png
#   inflating: /content/des/data/13951.png
#   inflating: /content/des/data/13975.png
#   inflating: /content/des/data/14031.png
#   inflating: /content/des/data/14090.png
#   inflating: /content/des/data/14188.png
#   inflating: /content/des/data/14226.png
#   inflating: /content/des/data/14270.png
#   inflating: /content/des/data/14387.png
#   inflating: /content/des/data/14395.png
#   inflating: /content/des/data/14399.png
#   inflating: /content/des/data/14494.png
#   inflating: /content/des/data/14504.png
#   inflating: /content/des/data/14559.png
#   inflating: /content/des/data/14576.png
#   inflating: /content/des/data/14579.png
#   inflating: /content/des/data/14590.png
#   inflating: /content/des/data/14687.png
#   inflating: /content/des/data/14739.png
#   inflating: /content/des/data/14743.png
#   inflating: /content/des/data/14776.png
#   inflating: /content/des/data/14802.png
#   inflating: /content/des/data/14838.png
#   inflating: /content/des/data/1488.png
#   inflating: /content/des/data/1490.png
#   inflating: /content/des/data/15046.png
#   inflating: /content/des/data/15071.png
#   inflating: /content/des/data/15074.png
#   inflating: /content/des/data/15081.png
#   inflating: /content/des/data/15118.png
#   inflating: /content/des/data/1512.png
#   inflating: /content/des/data/15176.png
#   inflating: /content/des/data/15218.png
#   inflating: /content/des/data/15223.png
#   inflating: /content/des/data/15270.png
#   inflating: /content/des/data/15272.png
#   inflating: /content/des/data/15306.png
#   inflating: /content/des/data/15356.png
#   inflating: /content/des/data/15472.png
#   inflating: /content/des/data/15473.png
#   inflating: /content/des/data/15494.png
#   inflating: /content/des/data/15540.png
#   inflating: /content/des/data/15600.png
#   inflating: /content/des/data/15641.png
#   inflating: /content/des/data/15660.png
#   inflating: /content/des/data/15683.png
#   inflating: /content/des/data/1569.png
#   inflating: /content/des/data/15721.png
#   inflating: /content/des/data/15742.png
#   inflating: /content/des/data/15767.png
#   inflating: /content/des/data/1578.png
#   inflating: /content/des/data/15942.png
#   inflating: /content/des/data/15957.png
#   inflating: /content/des/data/15971.png
#   inflating: /content/des/data/16014.png
#   inflating: /content/des/data/16015.png
#   inflating: /content/des/data/16027.png
#   inflating: /content/des/data/1604.png
#   inflating: /content/des/data/16110.png
#   inflating: /content/des/data/16184.png
#   inflating: /content/des/data/16230.png
#   inflating: /content/des/data/16301.png
#   inflating: /content/des/data/16453.png
#   inflating: /content/des/data/16465.png
#   inflating: /content/des/data/16539.png
#   inflating: /content/des/data/16601.png
#   inflating: /content/des/data/16681.png
#   inflating: /content/des/data/16751.png
#   inflating: /content/des/data/16752.png
#   inflating: /content/des/data/16818.png
#   inflating: /content/des/data/16844.png
#   inflating: /content/des/data/1686.png
#   inflating: /content/des/data/16871.png
#   inflating: /content/des/data/16933.png
#   inflating: /content/des/data/16984.png
#   inflating: /content/des/data/17019.png
#   inflating: /content/des/data/17024.png
#   inflating: /content/des/data/17025.png
#   inflating: /content/des/data/17105.png
#   inflating: /content/des/data/17138.png
#   inflating: /content/des/data/17145.png
#   inflating: /content/des/data/17158.png
#   inflating: /content/des/data/17199.png
#   inflating: /content/des/data/17293.png
#   inflating: /content/des/data/17299.png
#   inflating: /content/des/data/173.png
#   inflating: /content/des/data/17301.png
#   inflating: /content/des/data/17325.png
#   inflating: /content/des/data/17412.png
#   inflating: /content/des/data/17414.png
#   inflating: /content/des/data/17415.png
#   inflating: /content/des/data/17495.png
#   inflating: /content/des/data/17500.png
#   inflating: /content/des/data/17504.png
#   inflating: /content/des/data/17506.png
#   inflating: /content/des/data/17544.png
#   inflating: /content/des/data/17550.png
#   inflating: /content/des/data/17617.png
#   inflating: /content/des/data/17647.png
#   inflating: /content/des/data/17699.png
#   inflating: /content/des/data/17823.png
#   inflating: /content/des/data/17921.png
#   inflating: /content/des/data/18032.png
#   inflating: /content/des/data/18038.png
#   inflating: /content/des/data/18042.png
#   inflating: /content/des/data/1809.png
#   inflating: /content/des/data/18110.png
#   inflating: /content/des/data/18153.png
#   inflating: /content/des/data/1816.png
#   inflating: /content/des/data/18188.png
#   inflating: /content/des/data/1834.png
#   inflating: /content/des/data/18357.png
#   inflating: /content/des/data/18372.png
#   inflating: /content/des/data/18448.png
#   inflating: /content/des/data/18501.png
#   inflating: /content/des/data/18520.png
#   inflating: /content/des/data/18571.png
#   inflating: /content/des/data/18620.png
#   inflating: /content/des/data/18829.png
#   inflating: /content/des/data/18836.png
#   inflating: /content/des/data/18939.png
#   inflating: /content/des/data/19063.png
#   inflating: /content/des/data/1909.png
#   inflating: /content/des/data/19102.png
#   inflating: /content/des/data/19120.png
#   inflating: /content/des/data/19188.png
#   inflating: /content/des/data/19207.png
#   inflating: /content/des/data/19279.png
#   inflating: /content/des/data/19326.png
#   inflating: /content/des/data/19328.png
#   inflating: /content/des/data/19347.png
#   inflating: /content/des/data/1939.png
#   inflating: /content/des/data/19394.png
#   inflating: /content/des/data/19415.png
#   inflating: /content/des/data/19434.png
#   inflating: /content/des/data/19437.png
#   inflating: /content/des/data/19468.png
#   inflating: /content/des/data/19682.png
#   inflating: /content/des/data/19753.png
#   inflating: /content/des/data/19788.png
#   inflating: /content/des/data/19840.png
#   inflating: /content/des/data/19882.png
#   inflating: /content/des/data/19884.png
#   inflating: /content/des/data/19896.png
#   inflating: /content/des/data/19921.png
#   inflating: /content/des/data/1998.png
#   inflating: /content/des/data/20019.png
#   inflating: /content/des/data/20029.png
#   inflating: /content/des/data/20031.png
#   inflating: /content/des/data/20079.png
#   inflating: /content/des/data/20152.png
#   inflating: /content/des/data/20176.png
#   inflating: /content/des/data/20197.png
#   inflating: /content/des/data/20204.png
#   inflating: /content/des/data/20219.png
#   inflating: /content/des/data/20236.png
#   inflating: /content/des/data/20290.png
#   inflating: /content/des/data/2031.png
#   inflating: /content/des/data/20432.png
#   inflating: /content/des/data/20437.png
#   inflating: /content/des/data/20465.png
#   inflating: /content/des/data/20470.png
#   inflating: /content/des/data/20523.png
#   inflating: /content/des/data/20594.png
#   inflating: /content/des/data/20633.png
#   inflating: /content/des/data/20691.png
#   inflating: /content/des/data/20880.png
#   inflating: /content/des/data/20969.png
#   inflating: /content/des/data/21008.png
#   inflating: /content/des/data/21086.png
#   inflating: /content/des/data/21102.png
#   inflating: /content/des/data/2114.png
#   inflating: /content/des/data/21270.png
#   inflating: /content/des/data/21316.png
#   inflating: /content/des/data/21336.png
#   inflating: /content/des/data/21354.png
#   inflating: /content/des/data/21367.png
#   inflating: /content/des/data/21374.png
#   inflating: /content/des/data/2140.png
#   inflating: /content/des/data/21416.png
#   inflating: /content/des/data/21421.png
#   inflating: /content/des/data/21431.png
#   inflating: /content/des/data/21509.png
#   inflating: /content/des/data/21528.png
#   inflating: /content/des/data/21553.png
#   inflating: /content/des/data/21687.png
#   inflating: /content/des/data/21716.png
#   inflating: /content/des/data/21745.png
#   inflating: /content/des/data/21784.png
#   inflating: /content/des/data/21836.png
#   inflating: /content/des/data/21853.png
#   inflating: /content/des/data/22043.png
#   inflating: /content/des/data/22117.png
#   inflating: /content/des/data/22205.png
#   inflating: /content/des/data/22232.png
#   inflating: /content/des/data/22328.png
#   inflating: /content/des/data/22421.png
#   inflating: /content/des/data/22430.png
#   inflating: /content/des/data/22506.png
#   inflating: /content/des/data/22524.png
#   inflating: /content/des/data/22528.png
#   inflating: /content/des/data/22549.png
#   inflating: /content/des/data/2255.png
#   inflating: /content/des/data/22594.png
#   inflating: /content/des/data/22602.png
#   inflating: /content/des/data/22626.png
#   inflating: /content/des/data/22679.png
#   inflating: /content/des/data/2271.png
#   inflating: /content/des/data/22793.png
#   inflating: /content/des/data/2280.png
#   inflating: /content/des/data/22813.png
#   inflating: /content/des/data/22843.png
#   inflating: /content/des/data/22892.png
#   inflating: /content/des/data/22917.png
#   inflating: /content/des/data/22959.png
#   inflating: /content/des/data/230.png
#   inflating: /content/des/data/23001.png
#   inflating: /content/des/data/23034.png
#   inflating: /content/des/data/23095.png
#   inflating: /content/des/data/23125.png
#   inflating: /content/des/data/23198.png
#   inflating: /content/des/data/23251.png
#   inflating: /content/des/data/23307.png
#   inflating: /content/des/data/23323.png
#   inflating: /content/des/data/23366.png
#   inflating: /content/des/data/23379.png
#   inflating: /content/des/data/23402.png
#   inflating: /content/des/data/23484.png
#   inflating: /content/des/data/23499.png
#   inflating: /content/des/data/2354.png
#   inflating: /content/des/data/23586.png
#   inflating: /content/des/data/2367.png
#   inflating: /content/des/data/23689.png
#   inflating: /content/des/data/23728.png
#   inflating: /content/des/data/23853.png
#   inflating: /content/des/data/23858.png
#   inflating: /content/des/data/23861.png
#   inflating: /content/des/data/23881.png
#   inflating: /content/des/data/24005.png
#   inflating: /content/des/data/24014.png
#   inflating: /content/des/data/24023.png
#   inflating: /content/des/data/2405.png
#   inflating: /content/des/data/24089.png
#   inflating: /content/des/data/24092.png
#   inflating: /content/des/data/24182.png
#   inflating: /content/des/data/24331.png
#   inflating: /content/des/data/24391.png
#   inflating: /content/des/data/24407.png
#   inflating: /content/des/data/2444.png
#   inflating: /content/des/data/24444.png
#   inflating: /content/des/data/24560.png
#   inflating: /content/des/data/24705.png
#   inflating: /content/des/data/24728.png
#   inflating: /content/des/data/2475.png
#   inflating: /content/des/data/2481.png
#   inflating: /content/des/data/24818.png
#   inflating: /content/des/data/24857.png
#   inflating: /content/des/data/24904.png
#   inflating: /content/des/data/2494.png
#   inflating: /content/des/data/24945.png
#   inflating: /content/des/data/25009.png
#   inflating: /content/des/data/25034.png
#   inflating: /content/des/data/25059.png
#   inflating: /content/des/data/25082.png
#   inflating: /content/des/data/25137.png
#   inflating: /content/des/data/25220.png
#   inflating: /content/des/data/25257.png
#   inflating: /content/des/data/2526.png
#   inflating: /content/des/data/2528.png
#   inflating: /content/des/data/25379.png
#   inflating: /content/des/data/254.png
#   inflating: /content/des/data/25425.png
#   inflating: /content/des/data/2554.png
#   inflating: /content/des/data/25548.png
#   inflating: /content/des/data/25563.png
#   inflating: /content/des/data/25571.png
#   inflating: /content/des/data/25576.png
#   inflating: /content/des/data/25602.png
#   inflating: /content/des/data/2561.png
#   inflating: /content/des/data/25614.png
#   inflating: /content/des/data/25668.png
#   inflating: /content/des/data/25707.png
#   inflating: /content/des/data/25783.png
#   inflating: /content/des/data/25837.png
#   inflating: /content/des/data/25891.png
#   inflating: /content/des/data/25896.png
#   inflating: /content/des/data/25924.png
#   inflating: /content/des/data/25953.png
#   inflating: /content/des/data/26030.png
#   inflating: /content/des/data/26033.png
#   inflating: /content/des/data/26068.png
#   inflating: /content/des/data/26166.png
#   inflating: /content/des/data/26225.png
#   inflating: /content/des/data/26250.png
#   inflating: /content/des/data/26277.png
#   inflating: /content/des/data/26292.png
#   inflating: /content/des/data/26402.png
#   inflating: /content/des/data/26408.png
#   inflating: /content/des/data/26423.png
#   inflating: /content/des/data/26445.png
#   inflating: /content/des/data/26516.png
#   inflating: /content/des/data/26599.png
#   inflating: /content/des/data/26708.png
#   inflating: /content/des/data/26710.png
#   inflating: /content/des/data/26768.png
#   inflating: /content/des/data/2678.png
#   inflating: /content/des/data/26814.png
#   inflating: /content/des/data/26821.png
#   inflating: /content/des/data/26867.png
#   inflating: /content/des/data/26901.png
#   inflating: /content/des/data/26902.png
#   inflating: /content/des/data/26913.png
#   inflating: /content/des/data/26932.png
#   inflating: /content/des/data/26966.png
#   inflating: /content/des/data/26984.png
#   inflating: /content/des/data/27055.png
#   inflating: /content/des/data/27056.png
#   inflating: /content/des/data/27061.png
#   inflating: /content/des/data/27109.png
#   inflating: /content/des/data/27157.png
#   inflating: /content/des/data/27162.png
#   inflating: /content/des/data/27223.png
#   inflating: /content/des/data/27299.png
#   inflating: /content/des/data/27419.png
#   inflating: /content/des/data/27425.png
#   inflating: /content/des/data/2751.png
#   inflating: /content/des/data/27530.png
#   inflating: /content/des/data/27587.png
#   inflating: /content/des/data/27762.png
#   inflating: /content/des/data/2783.png
#   inflating: /content/des/data/2786.png
#   inflating: /content/des/data/2791.png
#   inflating: /content/des/data/27930.png
#   inflating: /content/des/data/27931.png
#   inflating: /content/des/data/27952.png
#   inflating: /content/des/data/28084.png
#   inflating: /content/des/data/28133.png
#   inflating: /content/des/data/28158.png
#   inflating: /content/des/data/28183.png
#   inflating: /content/des/data/28207.png
#   inflating: /content/des/data/28297.png
#   inflating: /content/des/data/28309.png
#   inflating: /content/des/data/28362.png
#   inflating: /content/des/data/28367.png
#   inflating: /content/des/data/28374.png
#   inflating: /content/des/data/28399.png
#   inflating: /content/des/data/28473.png
#   inflating: /content/des/data/28529.png
#   inflating: /content/des/data/28567.png
#   inflating: /content/des/data/28610.png
#   inflating: /content/des/data/28713.png
#   inflating: /content/des/data/28716.png
#   inflating: /content/des/data/28772.png
#   inflating: /content/des/data/2892.png
#   inflating: /content/des/data/28943.png
#   inflating: /content/des/data/28966.png
#   inflating: /content/des/data/28978.png
#   inflating: /content/des/data/29019.png
#   inflating: /content/des/data/29027.png
#   inflating: /content/des/data/29160.png
#   inflating: /content/des/data/29216.png
#   inflating: /content/des/data/29306.png
#   inflating: /content/des/data/2932.png
#   inflating: /content/des/data/29324.png
#   inflating: /content/des/data/29332.png
#   inflating: /content/des/data/2934.png
#   inflating: /content/des/data/29366.png
#   inflating: /content/des/data/29388.png
#   inflating: /content/des/data/29562.png
#   inflating: /content/des/data/29589.png
#   inflating: /content/des/data/29649.png
#   inflating: /content/des/data/29653.png
#   inflating: /content/des/data/29670.png
#   inflating: /content/des/data/29719.png
#   inflating: /content/des/data/29720.png
#   inflating: /content/des/data/2974.png
#   inflating: /content/des/data/29742.png
#   inflating: /content/des/data/29905.png
#   inflating: /content/des/data/29980.png
#   inflating: /content/des/data/30033.png
#   inflating: /content/des/data/30037.png
#   inflating: /content/des/data/30060.png
#   inflating: /content/des/data/30076.png
#   inflating: /content/des/data/30185.png
#   inflating: /content/des/data/30188.png
#   inflating: /content/des/data/30340.png
#   inflating: /content/des/data/30341.png
#   inflating: /content/des/data/30349.png
#   inflating: /content/des/data/30362.png
#   inflating: /content/des/data/30386.png
#   inflating: /content/des/data/30402.png
#   inflating: /content/des/data/30477.png
#   inflating: /content/des/data/30480.png
#   inflating: /content/des/data/30593.png
#   inflating: /content/des/data/30672.png
#   inflating: /content/des/data/30688.png
#   inflating: /content/des/data/30762.png
#   inflating: /content/des/data/30798.png
#   inflating: /content/des/data/3082.png
#   inflating: /content/des/data/3085.png
#   inflating: /content/des/data/30863.png
#   inflating: /content/des/data/30881.png
#   inflating: /content/des/data/30920.png
#   inflating: /content/des/data/30940.png
#   inflating: /content/des/data/31035.png
#   inflating: /content/des/data/31151.png
#   inflating: /content/des/data/31264.png
#   inflating: /content/des/data/3136.png
#   inflating: /content/des/data/31382.png
#   inflating: /content/des/data/31405.png
#   inflating: /content/des/data/31478.png
#   inflating: /content/des/data/31654.png
#   inflating: /content/des/data/31677.png
#   inflating: /content/des/data/31780.png
#   inflating: /content/des/data/31848.png
#   inflating: /content/des/data/31852.png
#   inflating: /content/des/data/3195.png
#   inflating: /content/des/data/31968.png
#   inflating: /content/des/data/31993.png
#   inflating: /content/des/data/32055.png
#   inflating: /content/des/data/3210.png
#   inflating: /content/des/data/3214.png
#   inflating: /content/des/data/32140.png
#   inflating: /content/des/data/32144.png
#   inflating: /content/des/data/32151.png
#   inflating: /content/des/data/32161.png
#   inflating: /content/des/data/32163.png
#   inflating: /content/des/data/32181.png
#   inflating: /content/des/data/32283.png
#   inflating: /content/des/data/32313.png
#   inflating: /content/des/data/32393.png
#   inflating: /content/des/data/32441.png
#   inflating: /content/des/data/32510.png
#   inflating: /content/des/data/32580.png
#   inflating: /content/des/data/32584.png
#   inflating: /content/des/data/32734.png
#   inflating: /content/des/data/33046.png
#   inflating: /content/des/data/33093.png
#   inflating: /content/des/data/33097.png
#   inflating: /content/des/data/33101.png
#   inflating: /content/des/data/33103.png
#   inflating: /content/des/data/33169.png
#   inflating: /content/des/data/33190.png
#   inflating: /content/des/data/33239.png
#   inflating: /content/des/data/33342.png
#   inflating: /content/des/data/33346.png
#   inflating: /content/des/data/33410.png
#   inflating: /content/des/data/33428.png
#   inflating: /content/des/data/33464.png
#   inflating: /content/des/data/3352.png
#   inflating: /content/des/data/33586.png
#   inflating: /content/des/data/33592.png
#   inflating: /content/des/data/33608.png
#   inflating: /content/des/data/33637.png
#   inflating: /content/des/data/33780.png
#   inflating: /content/des/data/33790.png
#   inflating: /content/des/data/3386.png
#   inflating: /content/des/data/33875.png
#   inflating: /content/des/data/33878.png
#   inflating: /content/des/data/33936.png
#   inflating: /content/des/data/33965.png
#   inflating: /content/des/data/33982.png
#   inflating: /content/des/data/34001.png
#   inflating: /content/des/data/3414.png
#   inflating: /content/des/data/34160.png
#   inflating: /content/des/data/34185.png
#   inflating: /content/des/data/34200.png
#   inflating: /content/des/data/34254.png
#   inflating: /content/des/data/34274.png
#   inflating: /content/des/data/3428.png
#   inflating: /content/des/data/34292.png
#   inflating: /content/des/data/34298.png
#   inflating: /content/des/data/34333.png
#   inflating: /content/des/data/34413.png
#   inflating: /content/des/data/34497.png
#   inflating: /content/des/data/34594.png
#   inflating: /content/des/data/34715.png
#   inflating: /content/des/data/34720.png
#   inflating: /content/des/data/34772.png
#   inflating: /content/des/data/3488.png
#   inflating: /content/des/data/3491.png
#   inflating: /content/des/data/34935.png
#   inflating: /content/des/data/34953.png
#   inflating: /content/des/data/34981.png
#   inflating: /content/des/data/35004.png
#   inflating: /content/des/data/35009.png
#   inflating: /content/des/data/35017.png
#   inflating: /content/des/data/35047.png
#   inflating: /content/des/data/35072.png
#   inflating: /content/des/data/35109.png
#   inflating: /content/des/data/35129.png
#   inflating: /content/des/data/35342.png
#   inflating: /content/des/data/35381.png
#   inflating: /content/des/data/3545.png
#   inflating: /content/des/data/35909.png
#   inflating: /content/des/data/3593.png
#   inflating: /content/des/data/35932.png
#   inflating: /content/des/data/35989.png
#   inflating: /content/des/data/35995.png
#   inflating: /content/des/data/36015.png
#   inflating: /content/des/data/36027.png
#   inflating: /content/des/data/36052.png
#   inflating: /content/des/data/36137.png
#   inflating: /content/des/data/36158.png
#   inflating: /content/des/data/3616.png
#   inflating: /content/des/data/36162.png
#   inflating: /content/des/data/36212.png
#   inflating: /content/des/data/36220.png
#   inflating: /content/des/data/36245.png
#   inflating: /content/des/data/36413.png
#   inflating: /content/des/data/36449.png
#   inflating: /content/des/data/36478.png
#   inflating: /content/des/data/36500.png
#   inflating: /content/des/data/36519.png
#   inflating: /content/des/data/36544.png
#   inflating: /content/des/data/36581.png
#   inflating: /content/des/data/36590.png
#   inflating: /content/des/data/36731.png
#   inflating: /content/des/data/36777.png
#   inflating: /content/des/data/36813.png
#   inflating: /content/des/data/36829.png
#   inflating: /content/des/data/36832.png
#   inflating: /content/des/data/36891.png
#   inflating: /content/des/data/36971.png
#   inflating: /content/des/data/36981.png
#   inflating: /content/des/data/37039.png
#   inflating: /content/des/data/3704.png
#   inflating: /content/des/data/37092.png
#   inflating: /content/des/data/37123.png
#   inflating: /content/des/data/37132.png
#   inflating: /content/des/data/37136.png
#   inflating: /content/des/data/37157.png
#   inflating: /content/des/data/3716.png
#   inflating: /content/des/data/37301.png
#   inflating: /content/des/data/37320.png
#   inflating: /content/des/data/37358.png
#   inflating: /content/des/data/37371.png
#   inflating: /content/des/data/37460.png
#   inflating: /content/des/data/3763.png
#   inflating: /content/des/data/37641.png
#   inflating: /content/des/data/37661.png
#   inflating: /content/des/data/37670.png
#   inflating: /content/des/data/37734.png
#   inflating: /content/des/data/37810.png
#   inflating: /content/des/data/3783.png
#   inflating: /content/des/data/37885.png
#   inflating: /content/des/data/37931.png
#   inflating: /content/des/data/37966.png
#   inflating: /content/des/data/38049.png
#   inflating: /content/des/data/38068.png
#   inflating: /content/des/data/38098.png
#   inflating: /content/des/data/38194.png
#   inflating: /content/des/data/38216.png
#   inflating: /content/des/data/38230.png
#   inflating: /content/des/data/38257.png
#   inflating: /content/des/data/38309.png
#   inflating: /content/des/data/38395.png
#   inflating: /content/des/data/38446.png
#   inflating: /content/des/data/38505.png
#   inflating: /content/des/data/38539.png
#   inflating: /content/des/data/3855.png
#   inflating: /content/des/data/38596.png
#   inflating: /content/des/data/38653.png
#   inflating: /content/des/data/38674.png
#   inflating: /content/des/data/3871.png
#   inflating: /content/des/data/38768.png
#   inflating: /content/des/data/38804.png
#   inflating: /content/des/data/38881.png
#   inflating: /content/des/data/38932.png
#   inflating: /content/des/data/38935.png
#   inflating: /content/des/data/38957.png
#   inflating: /content/des/data/38985.png
#   inflating: /content/des/data/39086.png
#   inflating: /content/des/data/39136.png
#   inflating: /content/des/data/39169.png
#   inflating: /content/des/data/39195.png
#   inflating: /content/des/data/392.png
#   inflating: /content/des/data/39260.png
#   inflating: /content/des/data/39271.png
#   inflating: /content/des/data/39273.png
#   inflating: /content/des/data/39329.png
#   inflating: /content/des/data/39346.png
#   inflating: /content/des/data/39400.png
#   inflating: /content/des/data/39690.png
#   inflating: /content/des/data/39774.png
#   inflating: /content/des/data/39813.png
#   inflating: /content/des/data/39851.png
#   inflating: /content/des/data/39942.png
#   inflating: /content/des/data/39945.png
#   inflating: /content/des/data/40104.png
#   inflating: /content/des/data/40130.png
#   inflating: /content/des/data/40156.png
#   inflating: /content/des/data/40357.png
#   inflating: /content/des/data/4038.png
#   inflating: /content/des/data/40447.png
#   inflating: /content/des/data/40518.png
#   inflating: /content/des/data/40627.png
#   inflating: /content/des/data/40631.png
#   inflating: /content/des/data/40693.png
#   inflating: /content/des/data/40713.png
#   inflating: /content/des/data/40727.png
#   inflating: /content/des/data/40757.png
#   inflating: /content/des/data/4077.png
#   inflating: /content/des/data/40830.png
#   inflating: /content/des/data/4090.png
#   inflating: /content/des/data/40974.png
#   inflating: /content/des/data/40978.png
#   inflating: /content/des/data/40999.png
#   inflating: /content/des/data/41040.png
#   inflating: /content/des/data/41103.png
#   inflating: /content/des/data/4113.png
#   inflating: /content/des/data/41159.png
#   inflating: /content/des/data/41183.png
#   inflating: /content/des/data/41331.png
#   inflating: /content/des/data/41354.png
#   inflating: /content/des/data/41419.png
#   inflating: /content/des/data/4147.png
#   inflating: /content/des/data/41514.png
#   inflating: /content/des/data/41528.png
#   inflating: /content/des/data/41579.png
#   inflating: /content/des/data/41582.png
#   inflating: /content/des/data/41694.png
#   inflating: /content/des/data/41725.png
#   inflating: /content/des/data/4188.png
#   inflating: /content/des/data/41950.png
#   inflating: /content/des/data/41952.png
#   inflating: /content/des/data/41969.png
#   inflating: /content/des/data/41993.png
#   inflating: /content/des/data/42064.png
#   inflating: /content/des/data/42079.png
#   inflating: /content/des/data/42118.png
#   inflating: /content/des/data/4222.png
#   inflating: /content/des/data/42285.png
#   inflating: /content/des/data/423.png
#   inflating: /content/des/data/42356.png
#   inflating: /content/des/data/42367.png
#   inflating: /content/des/data/42374.png
#   inflating: /content/des/data/4242.png
#   inflating: /content/des/data/42441.png
#   inflating: /content/des/data/42456.png
#   inflating: /content/des/data/42501.png
#   inflating: /content/des/data/42556.png
#   inflating: /content/des/data/42559.png
#   inflating: /content/des/data/42596.png
#   inflating: /content/des/data/42634.png
#   inflating: /content/des/data/42789.png
#   inflating: /content/des/data/4286.png
#   inflating: /content/des/data/42963.png
#   inflating: /content/des/data/42998.png
#   inflating: /content/des/data/4309.png
#   inflating: /content/des/data/43129.png
#   inflating: /content/des/data/43186.png
#   inflating: /content/des/data/4326.png
#   inflating: /content/des/data/43321.png
#   inflating: /content/des/data/43356.png
#   inflating: /content/des/data/4337.png
#   inflating: /content/des/data/43437.png
#   inflating: /content/des/data/43457.png
#   inflating: /content/des/data/43529.png
#   inflating: /content/des/data/43532.png
#   inflating: /content/des/data/43557.png
#   inflating: /content/des/data/43563.png
#   inflating: /content/des/data/4362.png
#   inflating: /content/des/data/43626.png
#   inflating: /content/des/data/4370.png
#   inflating: /content/des/data/43702.png
#   inflating: /content/des/data/43718.png
#   inflating: /content/des/data/43768.png
#   inflating: /content/des/data/43792.png
#   inflating: /content/des/data/43793.png
#   inflating: /content/des/data/43845.png
#   inflating: /content/des/data/43846.png
#   inflating: /content/des/data/44007.png
#   inflating: /content/des/data/44170.png
#   inflating: /content/des/data/44314.png
#   inflating: /content/des/data/44324.png
#   inflating: /content/des/data/44348.png
#   inflating: /content/des/data/44367.png
#   inflating: /content/des/data/44379.png
#   inflating: /content/des/data/4450.png
#   inflating: /content/des/data/44560.png
#   inflating: /content/des/data/44632.png
#   inflating: /content/des/data/44643.png
#   inflating: /content/des/data/44678.png
#   inflating: /content/des/data/44703.png
#   inflating: /content/des/data/44708.png
#   inflating: /content/des/data/4473.png
#   inflating: /content/des/data/44754.png
#   inflating: /content/des/data/44801.png
#   inflating: /content/des/data/44894.png
#   inflating: /content/des/data/44936.png
#   inflating: /content/des/data/44944.png
#   inflating: /content/des/data/44954.png
#   inflating: /content/des/data/44977.png
#   inflating: /content/des/data/45027.png
#   inflating: /content/des/data/45035.png
#   inflating: /content/des/data/45152.png
#   inflating: /content/des/data/45212.png
#   inflating: /content/des/data/45218.png
#   inflating: /content/des/data/45225.png
#   inflating: /content/des/data/45277.png
#   inflating: /content/des/data/45311.png
#   inflating: /content/des/data/45338.png
#   inflating: /content/des/data/45460.png
#   inflating: /content/des/data/4570.png
#   inflating: /content/des/data/45709.png
#   inflating: /content/des/data/45817.png
#   inflating: /content/des/data/45852.png
#   inflating: /content/des/data/45897.png
#   inflating: /content/des/data/45956.png
#   inflating: /content/des/data/46056.png
#   inflating: /content/des/data/46095.png
#   inflating: /content/des/data/46173.png
#   inflating: /content/des/data/46326.png
#   inflating: /content/des/data/46348.png
#   inflating: /content/des/data/46353.png
#   inflating: /content/des/data/46412.png
#   inflating: /content/des/data/46460.png
#   inflating: /content/des/data/4658.png
#   inflating: /content/des/data/46642.png
#   inflating: /content/des/data/46673.png
#   inflating: /content/des/data/46712.png
#   inflating: /content/des/data/4673.png
#   inflating: /content/des/data/46826.png
#   inflating: /content/des/data/46895.png
#   inflating: /content/des/data/46947.png
#   inflating: /content/des/data/470.png
#   inflating: /content/des/data/47009.png
#   inflating: /content/des/data/47045.png
#   inflating: /content/des/data/47126.png
#   inflating: /content/des/data/47234.png
#   inflating: /content/des/data/47273.png
#   inflating: /content/des/data/47286.png
#   inflating: /content/des/data/47322.png
#   inflating: /content/des/data/47373.png
#   inflating: /content/des/data/47439.png
#   inflating: /content/des/data/47460.png
#   inflating: /content/des/data/47524.png
#   inflating: /content/des/data/47527.png
#   inflating: /content/des/data/47540.png
#   inflating: /content/des/data/47557.png
#   inflating: /content/des/data/47667.png
#   inflating: /content/des/data/47849.png
#   inflating: /content/des/data/47865.png
#   inflating: /content/des/data/47899.png
#   inflating: /content/des/data/47916.png
#   inflating: /content/des/data/48008.png
#   inflating: /content/des/data/48041.png
#   inflating: /content/des/data/48053.png
#   inflating: /content/des/data/48059.png
#   inflating: /content/des/data/48119.png
#   inflating: /content/des/data/48171.png
#   inflating: /content/des/data/4830.png
#   inflating: /content/des/data/48308.png
#   inflating: /content/des/data/4837.png
#   inflating: /content/des/data/48427.png
#   inflating: /content/des/data/48437.png
#   inflating: /content/des/data/48444.png
#   inflating: /content/des/data/4848.png
#   inflating: /content/des/data/48488.png
#   inflating: /content/des/data/48525.png
#   inflating: /content/des/data/48615.png
#   inflating: /content/des/data/48650.png
#   inflating: /content/des/data/48685.png
#   inflating: /content/des/data/48720.png
#   inflating: /content/des/data/48773.png
#   inflating: /content/des/data/48799.png
#   inflating: /content/des/data/48859.png
#   inflating: /content/des/data/48904.png
#   inflating: /content/des/data/48961.png
#   inflating: /content/des/data/4902.png
#   inflating: /content/des/data/4904.png
#   inflating: /content/des/data/49090.png
#   inflating: /content/des/data/49134.png
#   inflating: /content/des/data/49141.png
#   inflating: /content/des/data/49199.png
#   inflating: /content/des/data/49263.png
#   inflating: /content/des/data/49265.png
#   inflating: /content/des/data/49364.png
#   inflating: /content/des/data/49457.png
#   inflating: /content/des/data/49641.png
#   inflating: /content/des/data/49761.png
#   inflating: /content/des/data/49764.png
#   inflating: /content/des/data/49787.png
#   inflating: /content/des/data/49816.png
#   inflating: /content/des/data/49826.png
#   inflating: /content/des/data/49836.png
#   inflating: /content/des/data/49841.png
#   inflating: /content/des/data/49907.png
#   inflating: /content/des/data/49926.png
#   inflating: /content/des/data/49940.png
#   inflating: /content/des/data/49979.png
#   inflating: /content/des/data/5063.png
#   inflating: /content/des/data/5115.png
#   inflating: /content/des/data/5270.png
#   inflating: /content/des/data/5278.png
#   inflating: /content/des/data/5355.png
#   inflating: /content/des/data/5499.png
#   inflating: /content/des/data/5508.png
#   inflating: /content/des/data/5535.png
#   inflating: /content/des/data/5616.png
#   inflating: /content/des/data/5653.png
#   inflating: /content/des/data/5711.png
#   inflating: /content/des/data/5745.png
#   inflating: /content/des/data/5798.png
#   inflating: /content/des/data/5801.png
#   inflating: /content/des/data/5822.png
#   inflating: /content/des/data/584.png
#   inflating: /content/des/data/5855.png
#   inflating: /content/des/data/5857.png
#   inflating: /content/des/data/5931.png
#   inflating: /content/des/data/5967.png
#   inflating: /content/des/data/598.png
#   inflating: /content/des/data/5997.png
#   inflating: /content/des/data/6090.png
#   inflating: /content/des/data/6109.png
#   inflating: /content/des/data/6118.png
#   inflating: /content/des/data/6148.png
#   inflating: /content/des/data/6199.png
#   inflating: /content/des/data/6206.png
#   inflating: /content/des/data/6219.png
#   inflating: /content/des/data/6236.png
#   inflating: /content/des/data/6257.png
#   inflating: /content/des/data/6307.png
#   inflating: /content/des/data/6322.png
#   inflating: /content/des/data/6325.png
#   inflating: /content/des/data/6406.png
#   inflating: /content/des/data/6434.png
#   inflating: /content/des/data/6463.png
#   inflating: /content/des/data/6596.png
#   inflating: /content/des/data/6620.png
#   inflating: /content/des/data/6625.png
#   inflating: /content/des/data/6691.png
#   inflating: /content/des/data/6714.png
#   inflating: /content/des/data/6753.png
#   inflating: /content/des/data/6764.png
#   inflating: /content/des/data/6842.png
#   inflating: /content/des/data/6848.png
#   inflating: /content/des/data/6884.png
#   inflating: /content/des/data/692.png
#   inflating: /content/des/data/6937.png
#   inflating: /content/des/data/6940.png
#   inflating: /content/des/data/6954.png
#   inflating: /content/des/data/703.png
#   inflating: /content/des/data/7034.png
#   inflating: /content/des/data/7194.png
#   inflating: /content/des/data/7206.png
#   inflating: /content/des/data/7291.png
#   inflating: /content/des/data/7292.png
#   inflating: /content/des/data/7310.png
#   inflating: /content/des/data/7315.png
#   inflating: /content/des/data/7356.png
#   inflating: /content/des/data/7403.png
#   inflating: /content/des/data/741.png
#   inflating: /content/des/data/7412.png
#   inflating: /content/des/data/7440.png
#   inflating: /content/des/data/7461.png
#   inflating: /content/des/data/7502.png
#   inflating: /content/des/data/7545.png
#   inflating: /content/des/data/7547.png
#   inflating: /content/des/data/7566.png
#   inflating: /content/des/data/761.png
#   inflating: /content/des/data/7616.png
#   inflating: /content/des/data/7667.png
#   inflating: /content/des/data/7805.png
#   inflating: /content/des/data/7813.png
#   inflating: /content/des/data/7836.png
#   inflating: /content/des/data/7850.png
#   inflating: /content/des/data/7853.png
#   inflating: /content/des/data/7907.png
#   inflating: /content/des/data/7932.png
#   inflating: /content/des/data/7941.png
#   inflating: /content/des/data/7947.png
#   inflating: /content/des/data/798.png
#   inflating: /content/des/data/7998.png
#   inflating: /content/des/data/8030.png
#   inflating: /content/des/data/8037.png
#   inflating: /content/des/data/8057.png
#   inflating: /content/des/data/8106.png
#   inflating: /content/des/data/8163.png
#   inflating: /content/des/data/8204.png
#   inflating: /content/des/data/8211.png
#   inflating: /content/des/data/8256.png
#   inflating: /content/des/data/8286.png
#   inflating: /content/des/data/8361.png
#   inflating: /content/des/data/8462.png
#   inflating: /content/des/data/85.png
#   inflating: /content/des/data/8521.png
#   inflating: /content/des/data/8581.png
#   inflating: /content/des/data/8605.png
#   inflating: /content/des/data/8650.png
#   inflating: /content/des/data/866.png
#   inflating: /content/des/data/8745.png
#   inflating: /content/des/data/8753.png
#   inflating: /content/des/data/8819.png
#   inflating: /content/des/data/8847.png
#   inflating: /content/des/data/8886.png
#   inflating: /content/des/data/8919.png
#   inflating: /content/des/data/8932.png
#   inflating: /content/des/data/9052.png
#   inflating: /content/des/data/9101.png
#   inflating: /content/des/data/9174.png
#   inflating: /content/des/data/9240.png
#   inflating: /content/des/data/9292.png
#   inflating: /content/des/data/9332.png
#   inflating: /content/des/data/9344.png
#   inflating: /content/des/data/9370.png
#   inflating: /content/des/data/9474.png
#   inflating: /content/des/data/9487.png
#   inflating: /content/des/data/9565.png
#   inflating: /content/des/data/9633.png
#   inflating: /content/des/data/9641.png
#   inflating: /content/des/data/9727.png
#   inflating: /content/des/data/9738.png
#   inflating: /content/des/data/9742.png
#   inflating: /content/des/data/9795.png
#   inflating: /content/des/data/9824.png
#   inflating: /content/des/data/9837.png
#   inflating: /content/des/data/9927.png
#   inflating: /content/des/data/10042.png
#   inflating: /content/des/data/10049.png
#   inflating: /content/des/data/1011.png
#   inflating: /content/des/data/10215.png
#   inflating: /content/des/data/10233.png
#   inflating: /content/des/data/10260.png
#   inflating: /content/des/data/10282.png
#   inflating: /content/des/data/10334.png
#   inflating: /content/des/data/10442.png
#   inflating: /content/des/data/10455.png
#   inflating: /content/des/data/10529.png
#   inflating: /content/des/data/10553.png
#   inflating: /content/des/data/1056.png
#   inflating: /content/des/data/10644.png
#   inflating: /content/des/data/10735.png
#   inflating: /content/des/data/10750.png
#   inflating: /content/des/data/10789.png
#   inflating: /content/des/data/10819.png
#   inflating: /content/des/data/10824.png
#   inflating: /content/des/data/10871.png
#   inflating: /content/des/data/10880.png
#   inflating: /content/des/data/10932.png
#   inflating: /content/des/data/10994.png
#   inflating: /content/des/data/11027.png
#   inflating: /content/des/data/1110.png
#   inflating: /content/des/data/11103.png
#   inflating: /content/des/data/11184.png
#   inflating: /content/des/data/11212.png
#   inflating: /content/des/data/11223.png
#   inflating: /content/des/data/11269.png
#   inflating: /content/des/data/11285.png
#   inflating: /content/des/data/11321.png
#   inflating: /content/des/data/11338.png
#   inflating: /content/des/data/11365.png
#   inflating: /content/des/data/11380.png
#   inflating: /content/des/data/11410.png
#   inflating: /content/des/data/11459.png
#   inflating: /content/des/data/11470.png
#   inflating: /content/des/data/11485.png
#   inflating: /content/des/data/1150.png
#   inflating: /content/des/data/11656.png
#   inflating: /content/des/data/11669.png
#   inflating: /content/des/data/11728.png
#   inflating: /content/des/data/11742.png
#   inflating: /content/des/data/11806.png
#   inflating: /content/des/data/11882.png
#   inflating: /content/des/data/11927.png
#   inflating: /content/des/data/11971.png
#   inflating: /content/des/data/12034.png
#   inflating: /content/des/data/12046.png
#   inflating: /content/des/data/1209.png
#   inflating: /content/des/data/12221.png
#   inflating: /content/des/data/12343.png
#   inflating: /content/des/data/12378.png
#   inflating: /content/des/data/12464.png
#   inflating: /content/des/data/1253.png
#   inflating: /content/des/data/12628.png
#   inflating: /content/des/data/12634.png
#   inflating: /content/des/data/1266.png
#   inflating: /content/des/data/12684.png
#   inflating: /content/des/data/12708.png
#   inflating: /content/des/data/12757.png
#   inflating: /content/des/data/12777.png
#   inflating: /content/des/data/12953.png
#   inflating: /content/des/data/12957.png
#   inflating: /content/des/data/12962.png
#   inflating: /content/des/data/13063.png
#   inflating: /content/des/data/13090.png
#   inflating: /content/des/data/13095.png
#   inflating: /content/des/data/13147.png
#   inflating: /content/des/data/13168.png
#   inflating: /content/des/data/13201.png
#   inflating: /content/des/data/13205.png
#   inflating: /content/des/data/13236.png
#   inflating: /content/des/data/13269.png
#   inflating: /content/des/data/13285.png
#   inflating: /content/des/data/13300.png
#   inflating: /content/des/data/13303.png
#   inflating: /content/des/data/13329.png
#   inflating: /content/des/data/13337.png
#   inflating: /content/des/data/13410.png
#   inflating: /content/des/data/13472.png
#   inflating: /content/des/data/13495.png
#   inflating: /content/des/data/13519.png
#   inflating: /content/des/data/13570.png
#   inflating: /content/des/data/13631.png
#   inflating: /content/des/data/13689.png
#   inflating: /content/des/data/13701.png
#   inflating: /content/des/data/13726.png
#   inflating: /content/des/data/13734.png
#   inflating: /content/des/data/13742.png
#   inflating: /content/des/data/13812.png
#   inflating: /content/des/data/13827.png
#   inflating: /content/des/data/13831.png
#   inflating: /content/des/data/13948.png
#   inflating: /content/des/data/14048.png
#   inflating: /content/des/data/14058.png
#   inflating: /content/des/data/14149.png
#   inflating: /content/des/data/14172.png
#   inflating: /content/des/data/14219.png
#   inflating: /content/des/data/1427.png
#   inflating: /content/des/data/14302.png
#   inflating: /content/des/data/14374.png
#   inflating: /content/des/data/1442.png
#   inflating: /content/des/data/14486.png
#   inflating: /content/des/data/14512.png
#   inflating: /content/des/data/14527.png
#   inflating: /content/des/data/14537.png
#   inflating: /content/des/data/14538.png
#   inflating: /content/des/data/14575.png
#   inflating: /content/des/data/14578.png
#   inflating: /content/des/data/14591.png
#   inflating: /content/des/data/1460.png
#   inflating: /content/des/data/14624.png
#   inflating: /content/des/data/14672.png
#   inflating: /content/des/data/14675.png
#   inflating: /content/des/data/14681.png
#   inflating: /content/des/data/1470.png
#   inflating: /content/des/data/14710.png
#   inflating: /content/des/data/14746.png
#   inflating: /content/des/data/14758.png
#   inflating: /content/des/data/14781.png
# ...
#   inflating: /content/des/data/38389.png
#   inflating: /content/des/data/38627.png
#   inflating: /content/des/data/3864.png
#   inflating: /content/des/data/38649.png
#   inflating: /content/des/data/3865.png
#   inflating: /content/des/data/38730.png
#   inflating: /content/des/data/3878.png
#   inflating: /content/des/data/38815.png
#   inflating: /content/des/data/38830.png
#   inflating: /content/des/data/38895.png
#   inflating: /content/des/data/389.png
#   inflating: /content/des/data/38966.png
#   inflating: /content/des/data/38993.png
#   inflating: /content/des/data/39000.png
#   inflating: /content/des/data/39025.png
#   inflating: /content/des/data/39078.png
#   inflating: /content/des/data/39082.png
#   inflating: /content/des/data/39141.png
#   inflating: /content/des/data/39220.png
#   inflating: /content/des/data/39236.png
#   inflating: /content/des/data/39301.png
#   inflating: /content/des/data/39314.png
#   inflating: /content/des/data/39356.png
#   inflating: /content/des/data/39396.png
#   inflating: /content/des/data/39411.png
#   inflating: /content/des/data/39499.png
#   inflating: /content/des/data/39507.png
#   inflating: /content/des/data/39514.png
#   inflating: /content/des/data/39555.png
#   inflating: /content/des/data/3959.png
#   inflating: /content/des/data/39596.png
#   inflating: /content/des/data/39635.png
#   inflating: /content/des/data/39666.png
#   inflating: /content/des/data/39728.png
#   inflating: /content/des/data/39763.png
#   inflating: /content/des/data/39768.png
#   inflating: /content/des/data/39797.png
#   inflating: /content/des/data/39853.png
#   inflating: /content/des/data/39899.png
#   inflating: /content/des/data/39904.png
#   inflating: /content/des/data/39920.png
#   inflating: /content/des/data/39973.png
#   inflating: /content/des/data/39981.png
#   inflating: /content/des/data/39986.png
#   inflating: /content/des/data/40026.png
#   inflating: /content/des/data/40079.png
#   inflating: /content/des/data/40120.png
#   inflating: /content/des/data/40228.png
#   inflating: /content/des/data/40305.png
#   inflating: /content/des/data/40319.png
#   inflating: /content/des/data/40331.png
#   inflating: /content/des/data/40361.png
#   inflating: /content/des/data/40417.png
#   inflating: /content/des/data/40458.png
#   inflating: /content/des/data/40498.png
#   inflating: /content/des/data/40691.png
#   inflating: /content/des/data/40793.png
#   inflating: /content/des/data/40817.png
#   inflating: /content/des/data/40822.png
#   inflating: /content/des/data/40867.png
#   inflating: /content/des/data/4089.png
#   inflating: /content/des/data/40898.png
#   inflating: /content/des/data/40951.png
#   inflating: /content/des/data/40955.png
#   inflating: /content/des/data/41013.png
#   inflating: /content/des/data/41053.png
#   inflating: /content/des/data/41058.png
#   inflating: /content/des/data/41112.png
#   inflating: /content/des/data/41138.png
#   inflating: /content/des/data/41169.png
#   inflating: /content/des/data/41198.png
#   inflating: /content/des/data/4120.png
#   inflating: /content/des/data/4135.png
#   inflating: /content/des/data/41413.png
#   inflating: /content/des/data/41498.png
#   inflating: /content/des/data/41537.png
#   inflating: /content/des/data/41625.png
#   inflating: /content/des/data/41705.png
#   inflating: /content/des/data/41714.png
#   inflating: /content/des/data/41736.png
#   inflating: /content/des/data/41781.png
#   inflating: /content/des/data/41785.png
#   inflating: /content/des/data/41806.png
#   inflating: /content/des/data/41872.png
#   inflating: /content/des/data/41873.png
#   inflating: /content/des/data/41899.png
#   inflating: /content/des/data/41904.png
#   inflating: /content/des/data/41915.png
#   inflating: /content/des/data/42009.png
#   inflating: /content/des/data/42083.png
#   inflating: /content/des/data/42126.png
#   inflating: /content/des/data/42154.png
#   inflating: /content/des/data/42185.png
#   inflating: /content/des/data/42256.png
#   inflating: /content/des/data/42331.png
#   inflating: /content/des/data/42337.png
#   inflating: /content/des/data/42358.png
#   inflating: /content/des/data/42458.png
#   inflating: /content/des/data/42497.png
#   inflating: /content/des/data/42509.png
#   inflating: /content/des/data/42523.png
#   inflating: /content/des/data/42547.png
#   inflating: /content/des/data/42586.png
#   inflating: /content/des/data/42605.png
#   inflating: /content/des/data/42613.png
#   inflating: /content/des/data/42652.png
#   inflating: /content/des/data/42683.png
#   inflating: /content/des/data/42738.png
#   inflating: /content/des/data/42758.png
#   inflating: /content/des/data/42817.png
#   inflating: /content/des/data/42866.png
#   inflating: /content/des/data/42883.png
#   inflating: /content/des/data/42896.png
#   inflating: /content/des/data/42940.png
#   inflating: /content/des/data/42997.png
#   inflating: /content/des/data/43018.png
#   inflating: /content/des/data/4303.png
#   inflating: /content/des/data/43224.png
#   inflating: /content/des/data/43230.png
#   inflating: /content/des/data/43243.png
#   inflating: /content/des/data/43244.png
#   inflating: /content/des/data/43271.png
#   inflating: /content/des/data/43296.png
#   inflating: /content/des/data/43329.png
#   inflating: /content/des/data/43386.png
#   inflating: /content/des/data/43436.png
#   inflating: /content/des/data/43501.png
#   inflating: /content/des/data/43545.png
#   inflating: /content/des/data/43577.png
#   inflating: /content/des/data/43705.png
#   inflating: /content/des/data/43708.png
#   inflating: /content/des/data/43736.png
#   inflating: /content/des/data/43738.png
#   inflating: /content/des/data/43842.png
#   inflating: /content/des/data/43895.png
#   inflating: /content/des/data/43907.png
#   inflating: /content/des/data/43920.png
#   inflating: /content/des/data/43953.png
#   inflating: /content/des/data/43956.png
#   inflating: /content/des/data/43969.png
#   inflating: /content/des/data/4402.png
#   inflating: /content/des/data/44116.png
#   inflating: /content/des/data/44131.png
#   inflating: /content/des/data/44154.png
#   inflating: /content/des/data/44192.png
#   inflating: /content/des/data/44220.png
#   inflating: /content/des/data/44279.png
#   inflating: /content/des/data/44287.png
#   inflating: /content/des/data/44319.png
#   inflating: /content/des/data/44323.png
#   inflating: /content/des/data/4442.png
#   inflating: /content/des/data/44458.png
#   inflating: /content/des/data/4463.png
#   inflating: /content/des/data/44636.png
#   inflating: /content/des/data/44656.png
#   inflating: /content/des/data/44799.png
#   inflating: /content/des/data/44802.png
#   inflating: /content/des/data/44820.png
#   inflating: /content/des/data/44869.png
#   inflating: /content/des/data/45066.png
#   inflating: /content/des/data/4511.png
#   inflating: /content/des/data/45113.png
#   inflating: /content/des/data/45173.png
#   inflating: /content/des/data/45210.png
#   inflating: /content/des/data/4523.png
#   inflating: /content/des/data/45331.png
#   inflating: /content/des/data/45408.png
#   inflating: /content/des/data/45457.png
#   inflating: /content/des/data/45494.png
#   inflating: /content/des/data/45506.png
#   inflating: /content/des/data/45524.png
#   inflating: /content/des/data/45528.png
#   inflating: /content/des/data/4555.png
#   inflating: /content/des/data/45633.png
#   inflating: /content/des/data/4565.png
#   inflating: /content/des/data/45723.png
#   inflating: /content/des/data/45733.png
#   inflating: /content/des/data/45784.png
#   inflating: /content/des/data/4583.png
#   inflating: /content/des/data/45851.png
#   inflating: /content/des/data/45858.png
#   inflating: /content/des/data/45940.png
#   inflating: /content/des/data/45951.png
#   inflating: /content/des/data/46014.png
#   inflating: /content/des/data/46033.png
#   inflating: /content/des/data/46035.png
#   inflating: /content/des/data/46122.png
#   inflating: /content/des/data/46155.png
#   inflating: /content/des/data/46216.png
#   inflating: /content/des/data/46342.png
#   inflating: /content/des/data/46365.png
#   inflating: /content/des/data/46369.png
#   inflating: /content/des/data/46375.png
#   inflating: /content/des/data/46384.png
#   inflating: /content/des/data/46392.png
#   inflating: /content/des/data/46413.png
#   inflating: /content/des/data/46456.png
#   inflating: /content/des/data/46466.png
#   inflating: /content/des/data/46569.png
#   inflating: /content/des/data/46584.png
#   inflating: /content/des/data/46597.png
#   inflating: /content/des/data/46683.png
#   inflating: /content/des/data/46727.png
#   inflating: /content/des/data/46746.png
#   inflating: /content/des/data/46784.png
#   inflating: /content/des/data/46819.png
#   inflating: /content/des/data/46839.png
#   inflating: /content/des/data/46856.png
#   inflating: /content/des/data/46876.png
#   inflating: /content/des/data/46943.png
#   inflating: /content/des/data/46963.png
#   inflating: /content/des/data/4698.png
#   inflating: /content/des/data/47050.png
#   inflating: /content/des/data/47063.png
#   inflating: /content/des/data/47083.png
#   inflating: /content/des/data/47220.png
#   inflating: /content/des/data/47271.png
#   inflating: /content/des/data/47285.png
#   inflating: /content/des/data/47367.png
#   inflating: /content/des/data/47440.png
#   inflating: /content/des/data/47495.png
#   inflating: /content/des/data/47503.png
#   inflating: /content/des/data/47517.png
#   inflating: /content/des/data/47555.png
#   inflating: /content/des/data/47666.png
#   inflating: /content/des/data/47668.png
#   inflating: /content/des/data/477.png
#   inflating: /content/des/data/4773.png
#   inflating: /content/des/data/47867.png
#   inflating: /content/des/data/47888.png
#   inflating: /content/des/data/47893.png
#   inflating: /content/des/data/47924.png
#   inflating: /content/des/data/4821.png
#   inflating: /content/des/data/4836.png
#   inflating: /content/des/data/48410.png
#   inflating: /content/des/data/48495.png
#   inflating: /content/des/data/48508.png
#   inflating: /content/des/data/48544.png
#   inflating: /content/des/data/4856.png
#   inflating: /content/des/data/48593.png
#   inflating: /content/des/data/48662.png
#   inflating: /content/des/data/48723.png
#   inflating: /content/des/data/48774.png
#   inflating: /content/des/data/48812.png
#   inflating: /content/des/data/48831.png
#   inflating: /content/des/data/48835.png
#   inflating: /content/des/data/48929.png
#   inflating: /content/des/data/48939.png
#   inflating: /content/des/data/4909.png
#   inflating: /content/des/data/49140.png
#   inflating: /content/des/data/49142.png
#   inflating: /content/des/data/49158.png
#   inflating: /content/des/data/49171.png
#   inflating: /content/des/data/49228.png
#   inflating: /content/des/data/49281.png
#   inflating: /content/des/data/49300.png
#   inflating: /content/des/data/49324.png
#   inflating: /content/des/data/49336.png
#   inflating: /content/des/data/49368.png
#   inflating: /content/des/data/49449.png
#   inflating: /content/des/data/49467.png
#   inflating: /content/des/data/49600.png
#   inflating: /content/des/data/49649.png
#   inflating: /content/des/data/49660.png
#   inflating: /content/des/data/49692.png
#   inflating: /content/des/data/49732.png
#   inflating: /content/des/data/49774.png
#   inflating: /content/des/data/49913.png
#   inflating: /content/des/data/49936.png
#   inflating: /content/des/data/49943.png
#   inflating: /content/des/data/49959.png
#   inflating: /content/des/data/49976.png
#   inflating: /content/des/data/49983.png
#   inflating: /content/des/data/49987.png
#   inflating: /content/des/data/500.png
#   inflating: /content/des/data/5002.png
#   inflating: /content/des/data/5047.png
#   inflating: /content/des/data/5066.png
#   inflating: /content/des/data/5111.png
#   inflating: /content/des/data/5163.png
#   inflating: /content/des/data/5479.png
#   inflating: /content/des/data/5554.png
#   inflating: /content/des/data/5629.png
#   inflating: /content/des/data/571.png
#   inflating: /content/des/data/5726.png
#   inflating: /content/des/data/5775.png
#   inflating: /content/des/data/5793.png
#   inflating: /content/des/data/5946.png
#   inflating: /content/des/data/6158.png
#   inflating: /content/des/data/6230.png
#   inflating: /content/des/data/6262.png
#   inflating: /content/des/data/6387.png
#   inflating: /content/des/data/6488.png
#   inflating: /content/des/data/6523.png
#   inflating: /content/des/data/655.png
#   inflating: /content/des/data/6553.png
#   inflating: /content/des/data/6591.png
#   inflating: /content/des/data/6601.png
#   inflating: /content/des/data/6619.png
#   inflating: /content/des/data/6677.png
#   inflating: /content/des/data/6733.png
#   inflating: /content/des/data/6740.png
#   inflating: /content/des/data/6743.png
#   inflating: /content/des/data/6760.png
#   inflating: /content/des/data/6840.png
#   inflating: /content/des/data/6865.png
#   inflating: /content/des/data/6993.png
#   inflating: /content/des/data/7012.png
#   inflating: /content/des/data/7076.png
#   inflating: /content/des/data/7086.png
#   inflating: /content/des/data/7142.png
#   inflating: /content/des/data/7153.png
#   inflating: /content/des/data/7205.png
#   inflating: /content/des/data/7305.png
#   inflating: /content/des/data/7314.png
#   inflating: /content/des/data/7428.png
#   inflating: /content/des/data/7507.png
#   inflating: /content/des/data/7567.png
#   inflating: /content/des/data/7599.png
#   inflating: /content/des/data/7607.png
#   inflating: /content/des/data/7619.png
#   inflating: /content/des/data/7681.png
#   inflating: /content/des/data/7769.png
#   inflating: /content/des/data/7799.png
#   inflating: /content/des/data/790.png
#   inflating: /content/des/data/7924.png
#   inflating: /content/des/data/806.png
#   inflating: /content/des/data/8077.png
#   inflating: /content/des/data/8102.png
#   inflating: /content/des/data/8165.png
#   inflating: /content/des/data/8203.png
#   inflating: /content/des/data/822.png
#   inflating: /content/des/data/8225.png
#   inflating: /content/des/data/8278.png
#   inflating: /content/des/data/8303.png
#   inflating: /content/des/data/8344.png
#   inflating: /content/des/data/8431.png
#   inflating: /content/des/data/8500.png
#   inflating: /content/des/data/8509.png
#   inflating: /content/des/data/8596.png
#   inflating: /content/des/data/8609.png
#   inflating: /content/des/data/8620.png
#   inflating: /content/des/data/8630.png
#   inflating: /content/des/data/8681.png
#   inflating: /content/des/data/8687.png
#   inflating: /content/des/data/8711.png
#   inflating: /content/des/data/8740.png
#   inflating: /content/des/data/88.png
#   inflating: /content/des/data/8823.png
#   inflating: /content/des/data/8865.png
#   inflating: /content/des/data/8898.png
#   inflating: /content/des/data/8915.png
#   inflating: /content/des/data/8985.png
#   inflating: /content/des/data/8997.png
#   inflating: /content/des/data/9007.png
#   inflating: /content/des/data/9035.png
#   inflating: /content/des/data/9053.png
#   inflating: /content/des/data/914.png
#   inflating: /content/des/data/9166.png
#   inflating: /content/des/data/9225.png
#   inflating: /content/des/data/9333.png
#   inflating: /content/des/data/9452.png
#   inflating: /content/des/data/950.png
#   inflating: /content/des/data/9518.png
#   inflating: /content/des/data/957.png
#   inflating: /content/des/data/9572.png
#   inflating: /content/des/data/9610.png
#   inflating: /content/des/data/9703.png
#   inflating: /content/des/data/9796.png
#   inflating: /content/des/data/9945.png
#   inflating: /content/des/data/9957.png
#   inflating: /content/des/data/9969.png
#   inflating: /content/des/data/9974.png
#   inflating: /content/des/data/999.png
#   inflating: /content/des/labels.csv

# %%
random_filename = random.choice([
    x for x in os.listdir("des/data/")
    if os.path.isfile(os.path.join("des/data/", x))
])
img = mpimg.imread("des/data/" + random_filename)
print("min value of random img", img.min())
print("max value of random img", img.max())
imgplot = plt.imshow(img)
# Out:
# min value of random img 0.0
# max value of random img 0.9098039

# %%
import cv2
img2 = cv2.imread("des/data/" + random_filename,0)
print("min value of random img", img2.min())
print("max value of random img", img2.max())
imgplot = plt.imshow(img2)
# Out:
# min value of random img 10
# max value of random img 221

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
from skimage import io
# img = io.imread('image.png', as_gray=True)
images = [io.imread(file, as_gray=True) for file in glob.glob("des/data/*.png")]

# %%
x = pd.DataFrame(np.array(images).reshape(10000, -1))
y = pd.read_csv('des/labels.csv')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
random_cat = (y_train[y_train['label'] == 'cat']).sample(1)
print(random_cat['label'].iloc[0])
img = mpimg.imread("des/data/" + str(random_cat['id'].iloc[0])+".png")
imgplot = plt.imshow(img)
# Out:
# cat

# %%
random_cat = y_train[y_train['label'] == 'horse'].sample(1)
print(random_cat['label'].iloc[0])
img = mpimg.imread("des/data/" + str(random_cat['id'].iloc[0])+".png")
imgplot = plt.imshow(img)
# Out:
# horse

# %%
len(y_train[y_train['label'] == 'horse']), len(y_train[y_train['label'] == 'cat'])
# Out:
# (3446, 3554)

# %%
len(y_test[y_test['label'] == 'horse']), len(y_test[y_test['label'] == 'cat'])
# Out:
# (1554, 1446)

# %%
fig = plt.figure()
ax = fig.add_subplot(211)
ax.bar(['test', 'train'], [len(y_test[y_test['label'] == 'cat']), len(y_train[y_train['label'] == 'cat'])])
plt.title("cat")
fig = plt.figure()
ax = fig.add_subplot(212)
ax.bar(['test', 'train'], [len(y_test[y_test['label'] == 'horse']), len(y_train[y_train['label'] == 'horse'])])
plt.title("horse")
# Out:
# Text(0.5, 1.0, 'horse')

# %%
y_train = y_train.iloc[:, 1]
y_test = y_test.iloc[:, 1]

# %%
from sklearn.preprocessing import OneHotEncoder 
import random as rand

# %% [markdown]
# # Dataloader

# %%
class Dataloader:
    '''
    This class prepares the dataset for the neural network.
    '''
    
    def __init__(self, data, labels, n_classes, batch_size=None, shuffle=False):
        '''
        This is the constructor. It gets dataset information and initializes the 
        Dataloader class fields.
            Parameters:
                data: features your dataset in pandas.Dataframe format.
                labels: labels of your dataset in pandas.Dataframe format.
                n_classes: number of classes you have in your dataset.
                batch_size: the number of samples that will be propagated through the network.
                shuffle: boolean value indicating whether or not the dataset should be shuffled
        '''

        assert len(data)==len(labels)
        self.__n_classes = n_classes
        self.__batch_size = batch_size
        self.__shuffle = shuffle
        self.__data = data
        self.__onehot_labels = self.__onehot(labels, self.__n_classes)
    
    def __onehot(self, labels, n_classes):
        '''
        This private method gets labels and provides one_hot vectors of labels.
        For categorical variables where no such ordinal relationship exists,
        the integer encoding is not enough.
        In this case, a one-hot encoding can be applied to the integer representation.
        This is where the integer encoded variable is removed, and a new binary variable is
        added for each unique integer value.
        example:
            red,    green,    blue
            1,      0,        0
            0,      1,        0
            0,      0,        1
                Parameters:
                        label: lables of your dataset in pandas.Dataframe format.
                        n_classes: number of classes you have in your dataset.
                
                Returns:
                    onehot_vectors: onehot vectors of the labels
        '''
        # TODO: Implement
        encoder = OneHotEncoder(categories = 'auto')
        X = encoder.fit_transform(labels.values.reshape(-1,1)).toarray()
        onehot_vectors = pd.DataFrame(X)
        return onehot_vectors
    
    def __shuffle_dataset(self):
        '''
        This private method shuffles your dataset.
        It uses data and onehot_labels to shuffle them
        symmetrical.
        '''
        # TODO: Implement
        rand = np.random.permutation(len(self.__data))
        self.__data = self.__data[rand]
        self.__onehot_labels = self.__onehot_labels[rand]
    
    def __iter__(self):
        '''
        The __iter__() function returns an iterator for the
        given object (array, set, tuple, etc., or custom objects).
        This will return your dataset in the batch_size given. This should
        be used to provide data for the neural network.
        '''
        
        if self.__shuffle:
            self.__shuffle_dataset()
            
        if self.__batch_size==None:
            yield (np.matrix(self.__data), np.matrix(self.__onehot_labels))
            return
            
        for idx in range(0, len(self.__data), self.__batch_size):
            yield (np.matrix(self.__data[idx:idx+self.__batch_size]), 
                   np.matrix(self.__onehot_labels[idx:idx+self.__batch_size]))

# %% [markdown]
# # Activation Functions

# %%
class Identical:
    
    
    def __init__(self): pass
        
    def __val(self, matrix):
        
        identical_value = np.matrix(matrix, dtype=float)
        return identical_value

    def derivative(self, matrix):
        
        temp = np.matrix(matrix, dtype=float)
        identical_derivative = np.matrix(np.full(np.shape(temp), 1.))
        return identical_derivative
    
    def __call__(self, matrix):
        
        return self.__val(matrix)
    

class Relu:
    
    
    def __init__(self): pass
        
    
    def __val(self, matrix):
        
        # TODO: Implement
        relu_value = np.matrix(matrix, dtype=float)
        relu_value[relu_value<0] = 0.0
        return relu_value

    def derivative(self, matrix):
        
        # TODO: Implement
        relu_derivative = np.matrix(matrix, dtype=float)
        relu_derivative[relu_derivative > 0] = 1.
        relu_derivative[relu_derivative < 0] = 0.
        return relu_derivative
    
    def __call__(self, matrix):
        
        return self.__val(matrix)

    
class LeakyRelu:
    
    
    def __init__(self, negative_slope=0.01):
        
        self.negative_slope = 0.01
    
    def __val(self, matrix):
        
        # TODO: Implement
       
        leacky_relu_value = np.matrix(matrix, dtype=float)
        leacky_relu_value = np.where(leacky_relu_value > 0, leacky_relu_value, 0.1 * leacky_relu_value)
        return leacky_relu_value

    def derivative(self, matrix):
        
        # TODO: Implement
        leacky_relu_derivative = np.matrix(matrix, dtype=float)
        leacky_relu_derivative = np.where(leacky_relu_derivative > 0., 1, 0.1 )
        return leacky_relu_derivative
    
    def __call__(self, matrix):
        
        return self.__val(matrix)

    
class Sigmoid:
    
    
    def __init__(self): pass

    def __val(self, matrix):
        
        # TODO: Implement
        sigmoid_value = np.negative(matrix, dtype=float)
        sigmoid_value = np.matrix(1./(1 + np.exp(sigmoid_value)), dtype = float)
        return sigmoid_value

    def derivative(self, matrix):
        
        # TODO: Implement
        sigmoid_value = np.negative(matrix, dtype=float)
        sigmoid_value = np.matrix(1./(1 + np.exp(sigmoid_value)), dtype = float)
        sigmoid_value_minus_one = np.matrix(sigmoid_value + (-1))
        sigmoid_derivative = np.multiply(np.squeeze(sigmoid_value), np.squeeze(sigmoid_value_minus_one), out=None) 
        return sigmoid_derivative
    
    def __call__(self, matrix):
        
        return self.__val(matrix)


class Softmax:
    
    def __init__(self): pass
        
    def __val(self, matrix):
        
        # TODO: Implement
        # print(matrix.shape)
        # print(matrix.max(1).shape)
        matrix -= np.column_stack((matrix.max(1),  matrix.max(1)))
        
        softmax_value = np.matrix(np.exp(matrix)/np.column_stack((np.exp(matrix).sum(1), np.exp(matrix).sum(1))), dtype=float)
        return softmax_value
    
    def __call__(self, matrix):
        
        return self.__val(matrix)
    
class Tanh:
    
    def __init__(self): pass
      
    def __val(self, matrix):
        
        # TODO: Implement
        temp = np.matrix(matrix, dtype=float)
        tanh_value = np.tanh(temp)
        return tanh_value

    def derivative(self, matrix):
        
        # TODO: Implement
        tanh_value = self.__val(matrix)
        tanh_derivative = 1 - np.multiply(tanh_value, tanh_value)
        return tanh_derivative
    
    def __call__(self, matrix):
        
        return self.__val(matrix)

# %% [markdown]
# # Loss Function

# %%
class CrossEntropy: #(with softmax)
    
    
    def __init__(self): pass
        

    def __val(self, true_val, expected_val):
        
        assert np.shape(true_val)==np.shape(expected_val)
        # TODO: Implement
        s = Softmax()(true_val)
        # cross_entropy_value = -np.multiply(expected_val, np.ma.log(s)).sum(1)
        cross_entropy_value = np.sum(-np.multiply(np.matrix(expected_val, dtype=float),np.log(s)), axis=1)
        return cross_entropy_value
        
    def derivative(self, true_val, expected_val):
        
        assert np.shape(true_val)==np.shape(expected_val)
        # TODO: Implement
        s = Softmax()(true_val)
        cross_entropy_derivative = s - expected_val
        return cross_entropy_derivative
    
    def __call__(self, true_val, expected_val):
        
        return self.__val(true_val, expected_val)

# %% [markdown]
# # Layer

# %%
class Layer:
    '''
    The layer class is used to define neural network layers.
    It stores all needed information for each layer, such as neurons count,
    weight matrix, bias, the output after applying the activation function, etc.
    '''

    DEFAULT_LOW, DEFAULT_HIGH, DEFAULT_MEAN, DEFAULT_VAR = 0, 0.05, 0., 1.
  
    def __init__(self, input_size, output_size, activation=Identical(), initial_weight='uniform', 
                 **initializing_parameters):
        '''
        Parameters:
            input_size: the size of the input of this layer.
            output_size: the size of the output after this layer.
            activation: the activation function. It can be initialized to either of the previously defined activation classes.
                               default is an Identical activation function.
            initial_weight: either normal or uniform. It defines the method for weight initialization.
        '''
        
        assert type(initial_weight)==str, 'Undefined activation function!'
        
        self.__weight_initializer_dict = {'uniform':self.__uniform_weight, 'normal':self.__normal_weight}
        
        assert initial_weight in self.__weight_initializer_dict, 'Undefined weight initialization function!'


        self.__n_neurons = output_size
        weight_initializer = self.__weight_initializer_dict[initial_weight]
        self.__weight = weight_initializer(input_size, self.__n_neurons, **initializing_parameters)
        self.__bias = weight_initializer(1, self.__n_neurons, **initializing_parameters)
        self.__activation = activation
        
        self.__last_input = None
        self.__last_activation_input = None
        self.__last_activation_output = None
        self.__last_activation_derivative = None
        
    def forward(self, layer_input):
        '''
        It calculates the output of this layer for the layer_input argument.
        This method also stores __last_input, __last_activation_input, and __last_activation_derivative
        for future use in backpropagation.
        Parameters:
            layer_input: 2d np.matrix representing the input matrix of this layer.
        Returns:
            Final output of this layer after applying the activation function.
        '''
        assert np.ndim(layer_input)==2
        assert np.size(self.__weight,0) == np.size(layer_input,1)
        # TODO: Implement
        self.__last_input = layer_input
        self.__last_activation_input = np.matmul(layer_input, self.__weight) + self.__bias
        self.__last_activation_output = self.__activation(self.__last_activation_input)
        self.__last_activation_derivative = self.__activation.derivative(self.__last_activation_input)
        return self.__last_activation_output
    
    def update_weights(self, backprop_tensor, lr):
        '''
        It updates Layer weights according to the backpropagation matrix and learning rate.
        This method updates bias values as well.
        Parameters:
            backprop_tensor: 2d np.matrix passed from the next layer containing gradient values.
            lr: learning rate
        Returns:
            backprop_tensor to be used by the previous layer.
        '''
        assert np.ndim(backprop_tensor)==2
        assert np.size(backprop_tensor,0) == np.size(self.__last_activation_derivative,0)
        assert np.size(backprop_tensor,1) == self.__n_neurons
        # TODO: Implement
        tp = self.__last_input.transpose()
        errory = np.multiply(backprop_tensor,self.__last_activation_derivative)
        errorw = np.matmul(tp,errory)
        backprop_tensor = np.matmul(errory,self.__weight.transpose())
        self.__weight -= errorw*lr
        bu = np.matmul(np.matrix(np.tile(1, (1, errory.shape[0]))),errory)
        self.__bias -= bu*lr
        return backprop_tensor

    def __uniform_weight(self, dim1, dim2, **initializing_parameters):
        '''
        Initializes weights as a uniform distribution between low and high values.
        It uses default low and high values unless low or high are passed in initializing_parameters.
        Parameters:
            dim1: the size of the first dimension of weights.
            dim2: the size of the second dimension of weights.
            initializing_parameters: other initializing parameters; it can include custom low or high values.
        Returns:
            np.matrix with size (dim1, dim2) initialized using uniformly distributed values.
        '''
        low, high = self.DEFAULT_LOW, self.DEFAULT_HIGH
        if 'low' in initializing_parameters.keys(): low = initializing_parameters['low']
        if 'high' in initializing_parameters.keys(): high = initializing_parameters['high']
        # TODO: Implement
        # weights = [[0]* dim2]*dim1
        # for i in range(dim1):
        #     for j in range(dim2):
        #         weights[i][j] = np.float32(rand.uniform(low, high))
        # weights = np.array(weights)
        weights = np.random.uniform(low = low, high = high, size = (dim1, dim2))
        return weights

    def __normal_weight(self, dim1, dim2, **initializing_parameters):
        '''
        Initializes weights as a normal distribution with mean and var values.
        It uses default mean and variance values unless mean or var are passed in initializing_parameters.
        Parameters:
            dim1: the size of the first dimension of weights.
            dim2: the size of the second dimension of weights.
            initializing_parameters: other initializing parameters; it can include custom mean or var values.
        Returns:
            np.matrix with size (dim1, dim2) initialized using normaly distributed values.
        ''' 
        mean, var = self.DEFAULT_MEAN, self.DEFAULT_VAR
        if 'mean' in initializing_parameters.keys(): mean = initializing_parameters['mean']
        if 'var' in initializing_parameters.keys(): var = initializing_parameters['var']
        # TODO: Implement
        weights = [[0]* dim2] * dim1
        sd = np.sqrt(var)
        for i in range(dim1):
            for j in range(dim2):
                weights[i][j] = np.float32(rand.normal(0.0, sd))
        return weights
    
    @property
    def n_neurons(self): return self.__n_neurons
    
    @property
    def weight(self): return self.__weight
    
    @property
    def bias(self): return self.__bias
    
    @property
    def activation(self): return self.__activation

# %% [markdown]
# # Feed Forward Neural Network

# %%
class FeedForwardNN:
    
    def __init__(self, input_shape):
        
        
        self.__input_shape = input_shape
        self.__output_shape = None
        
        self.__layers_list = []
        
        self.__lr = None
        self.__loss = None

        
    def add_layer(self, n_neurons, activation=Relu(), initial_weight='uniform', **initializing_parameters):
        
         
        assert type(n_neurons)==int, "Invalid number of neurons for the layer!"
        assert n_neurons>0, "Invalid number of neurons for the layer!"
        
        n_prev_neurons = self.__input_shape if len(self.__layers_list)==0 else self.__layers_list[-1].n_neurons
        new_layer = Layer(n_prev_neurons, n_neurons, activation, initial_weight, **initializing_parameters)
        self.__layers_list.append(new_layer)
        self.__output_shape = self.__layers_list[-1].n_neurons 
      
    
    def set_training_param(self, loss=CrossEntropy(), lr=1e-3):
        
        assert self.__layers_list, "Uncomplete model!"
        self.__loss = loss
        self.__lr = lr
    
    
    def forward(self, network_input):
        
        assert type(self.__output_shape) != None, "Model is not compiled!"
        # TODO: Implement
        for i in self.__layers_list:
            network_output = i.forward(network_input)
            network_input = network_output
        return network_output
    
    
    def fit(self, epochs, trainloader, testloader=None, print_results=True):
        
        
        assert type(self.__output_shape) != None, "Model is not compiled!"
        assert type(self.__lr) != None and type(self.__loss) != None, "Training paramenters are not set!"

        log = {"train_accuracy":[], "train_loss":[], "test_accuracy":[], "test_loss":[]}
        
        for epoch in range(1, epochs+1):
            
            if print_results: 
                print('Epoch {}:'.format(epoch)) 
                
            average_accuracy, average_loss = self.__train(trainloader)
            log['train_accuracy'].append(average_accuracy)
            log['train_loss'].append(average_loss)
            if print_results:
                print('\tTrain: Average Accuracy: {}\tAverage Loss: {}'.format(average_accuracy, average_loss))
            
            if type(testloader) != type(None):
                average_accuracy, average_loss = self.__test(testloader)
                log['test_accuracy'].append(average_accuracy)
                log['test_loss'].append(average_loss)
                if print_results:
                    print('\tTest: Average Accuracy: {}\tAverage Loss: {}'.format(average_accuracy, average_loss))
                    
        return log
    
    
    def __train(self, trainloader):
        
        bach_accuracies, batch_losses = [], []
        for x_train, y_train in trainloader:
            
            batch_accuracy, batch_loss = self.__train_on_batch(x_train, y_train)
            bach_accuracies.append(batch_accuracy)
            batch_losses.append(batch_loss)
        return np.mean(bach_accuracies), np.mean(batch_losses)
    
    
    def __test(self, testloader):
        
        bach_accuracies, batch_losses = [], []
        for x_test, y_test in testloader:
            batch_accuracy, batch_loss = self.__test_on_batch(x_test, y_test)
            bach_accuracies.append(batch_accuracy)
            batch_losses.append(batch_loss)
        return np.mean(bach_accuracies), np.mean(batch_losses)

    
    def __train_on_batch(self, x_batch, y_batch):
        
        # TODO: Implement
        output = self.forward(x_batch)
        self.__update_weights(output, y_batch)
        batch_accuracy = self.__compute_accuracy(output, y_batch)
        batch_average_loss = np.mean(self.__loss.__call__(output, y_batch))
        # cross_entropy = CrossEntropy()
        # batch_loss = cross_entropy(output, y_batch)
        # batch_average_loss = np.sum(batch_loss)/len(output)
        return (batch_accuracy, batch_average_loss)
        
        
    def __test_on_batch(self, x_batch, y_batch):
        
        # TODO: Implement
        output = self.forward(x_batch)
        batch_accuracy = self.__compute_accuracy(output, y_batch)
        batch_average_loss = np.mean(self.__loss.__call__(output, y_batch))
        return (batch_accuracy, batch_average_loss)
            
        
    def __get_labels(self, outputs):
        
        # TODO: Implement
        labels = outputs.argmax(axis=1)
        return labels
    
    
    def __compute_accuracy(self, output, expected_output):
        
        # TODO: Implement
        output = np.array(output)
        _output = np.argmax(output, axis=1)
        expected_output = np.array(expected_output)
        _expected_output = np.argmax(expected_output, axis=1)
        truePrediced = np.sum(_output == _expected_output)
        accuracy = truePrediced/len(_output)*100
        return accuracy
    
    
    def __update_weights(self, output, y_train):
        
        # TODO: Implement
        temp = self.__loss.derivative(output, y_train)
        for i in reversed(self.__layers_list):
            temp = i.update_weights(temp, self.__lr)
        return

# %% [markdown]
# # Training Sample Code

# %%
# Sample code for building and training a model

INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=Relu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in multiply
#   del sys.path[0]
# 	Train: Average Accuracy: 49.980974124809734	Average Loss: nan
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6995182992492676
# Epoch 2:
# 	Train: Average Accuracy: 50.90848554033485	Average Loss: 0.6963541919092406
# 	Test: Average Accuracy: 51.684397163120565	Average Loss: 0.6942104600909272
# Epoch 3:
# 	Train: Average Accuracy: 50.342465753424655	Average Loss: 0.6939364561717202
# 	Test: Average Accuracy: 51.57358156028369	Average Loss: 0.6932307497252439
# Epoch 4:
# 	Train: Average Accuracy: 51.27473363774734	Average Loss: 0.6930707506026049
# 	Test: Average Accuracy: 51.42952127659574	Average Loss: 0.6931544329870621
# Epoch 5:
# 	Train: Average Accuracy: 51.77416286149163	Average Loss: 0.6925737999656753
# 	Test: Average Accuracy: 51.628989361702125	Average Loss: 0.6931712786171056
# Epoch 6:
# 	Train: Average Accuracy: 52.0880898021309	Average Loss: 0.6921800304052655
# 	Test: Average Accuracy: 51.36303191489362	Average Loss: 0.6933225659987731
# Epoch 7:
# 	Train: Average Accuracy: 52.40201674277017	Average Loss: 0.69183358914512
# 	Test: Average Accuracy: 51.263297872340424	Average Loss: 0.6934927425123205
# Epoch 8:
# 	Train: Average Accuracy: 52.75875190258753	Average Loss: 0.6914687887682662
# 	Test: Average Accuracy: 51.263297872340424	Average Loss: 0.6937449194272678
# Epoch 9:
# 	Train: Average Accuracy: 52.77302130898022	Average Loss: 0.6910578008048864
# 	Test: Average Accuracy: 51.23005319148936	Average Loss: 0.6940420101709676
# Epoch 10:
# 	Train: Average Accuracy: 53.144025875190266	Average Loss: 0.6906329773157475
# 	Test: Average Accuracy: 51.59574468085106	Average Loss: 0.6943131005308179
# Epoch 11:
# 	Train: Average Accuracy: 53.58637747336378	Average Loss: 0.6901997279980554
# 	Test: Average Accuracy: 51.69547872340426	Average Loss: 0.6947788467944473
# Epoch 12:
# 	Train: Average Accuracy: 53.40087519025876	Average Loss: 0.6897892787411154
# 	Test: Average Accuracy: 51.9281914893617	Average Loss: 0.6950016625475463
# Epoch 13:
# 	Train: Average Accuracy: 53.843226788432275	Average Loss: 0.6891965049174296
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6952380540230269
# Epoch 14:
# 	Train: Average Accuracy: 54.085806697108076	Average Loss: 0.6886595037257265
# 	Test: Average Accuracy: 51.78413120567375	Average Loss: 0.6955019272356548
# Epoch 15:
# 	Train: Average Accuracy: 54.18569254185693	Average Loss: 0.6881243405946327
# 	Test: Average Accuracy: 51.55141843971631	Average Loss: 0.6964472083626753
# Epoch 16:
# 	Train: Average Accuracy: 54.65658295281583	Average Loss: 0.6873980812746342
# 	Test: Average Accuracy: 51.48492907801418	Average Loss: 0.6968665731219681
# Epoch 17:
# 	Train: Average Accuracy: 54.9847792998478	Average Loss: 0.6866722892681982
# 	Test: Average Accuracy: 51.130319148936174	Average Loss: 0.6974209982242984
# Epoch 18:
# 	Train: Average Accuracy: 55.156012176560125	Average Loss: 0.6858917382943793
# 	Test: Average Accuracy: 51.329787234042556	Average Loss: 0.6987224366701571
# Epoch 19:
# 	Train: Average Accuracy: 55.38432267884323	Average Loss: 0.685057024844286
# 	Test: Average Accuracy: 51.4738475177305	Average Loss: 0.6993407604497028
# Epoch 20:
# 	Train: Average Accuracy: 55.79813546423136	Average Loss: 0.6840395706733048
# 	Test: Average Accuracy: 51.64007092198582	Average Loss: 0.6995842861647632
# Epoch 21:
# 	Train: Average Accuracy: 56.01217656012177	Average Loss: 0.6831405587264268
# 	Test: Average Accuracy: 51.628989361702125	Average Loss: 0.7013120493177948
# Epoch 22:
# 	Train: Average Accuracy: 56.49733637747337	Average Loss: 0.6818549000223367
# 	Test: Average Accuracy: 51.52925531914894	Average Loss: 0.701132285222383
# Epoch 23:
# 	Train: Average Accuracy: 56.62576103500761	Average Loss: 0.6807083409999596
# 	Test: Average Accuracy: 51.263297872340424	Average Loss: 0.7018160614643831
# Epoch 24:
# 	Train: Average Accuracy: 57.00152207001521	Average Loss: 0.6798646056585397
# 	Test: Average Accuracy: 51.5625	Average Loss: 0.7039274542419921
# Epoch 25:
# 	Train: Average Accuracy: 57.35825722983257	Average Loss: 0.6783525586531373
# 	Test: Average Accuracy: 51.496010638297875	Average Loss: 0.7045918419299844

# %% [markdown]
# قسمت سوم تاثیر لرنینگ ریت:

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.01
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=Relu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in multiply
#   del sys.path[0]
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: nan
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 2:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 3:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 4:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 5:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 6:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 7:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 8:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 9:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 10:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 11:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 12:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 13:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 14:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 15:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 16:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 17:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 18:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 19:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 20:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 21:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 22:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 23:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 24:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634
# Epoch 25:
# 	Train: Average Accuracy: 49.92389649923896	Average Loss: 0.6946608976457601
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.6929690369545634

# %% [markdown]
# با افزایش لرنینگ ریت دقت کمتر شد و لاس بهبودی نیافت زیرا مقادیر وزن ها واگرا میشوند و یادگیری خاصی صورت نمیگیرد.

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.0001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=Relu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 49.9476788432268	Average Loss: 20.52480079640831
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 27.83139379233007
# Epoch 2:
# 	Train: Average Accuracy: 50.50418569254186	Average Loss: 15.832199871118126
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 22.245031779815747
# Epoch 3:
# 	Train: Average Accuracy: 50.18074581430745	Average Loss: 12.548161236304079
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 1.279587212662533
# Epoch 4:
# 	Train: Average Accuracy: 50.35197869101978	Average Loss: 9.448129515239819
# 	Test: Average Accuracy: 48.24911347517731	Average Loss: 5.614732407593026
# Epoch 5:
# 	Train: Average Accuracy: 50.646879756468806	Average Loss: 7.311761091343842
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 9.512705254580444
# Epoch 6:
# 	Train: Average Accuracy: 50.618340943683414	Average Loss: 5.693924616599017
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 7.097131383906906
# Epoch 7:
# 	Train: Average Accuracy: 50.466133942161335	Average Loss: 4.399418278440866
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 1.773241407315528
# Epoch 8:
# 	Train: Average Accuracy: 50.35197869101978	Average Loss: 3.442670726467418
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 1.0192175478101115
# Epoch 9:
# 	Train: Average Accuracy: 50.632610350076106	Average Loss: 2.6495796315449094
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 2.835696144447164
# Epoch 10:
# 	Train: Average Accuracy: 50.36149162861492	Average Loss: 2.1032409723932686
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 2.1574384362610113
# Epoch 11:
# 	Train: Average Accuracy: 50.80384322678844	Average Loss: 1.6281768591787058
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 1.2919078429894788
# Epoch 12:
# 	Train: Average Accuracy: 51.68854642313547	Average Loss: 1.29167195587391
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 1.161294339873809
# Epoch 13:
# 	Train: Average Accuracy: 51.12252663622526	Average Loss: 1.1296250274613309
# 	Test: Average Accuracy: 48.24911347517731	Average Loss: 0.7545570326828651
# Epoch 14:
# 	Train: Average Accuracy: 50.80859969558599	Average Loss: 1.0027504621593786
# 	Test: Average Accuracy: 48.21586879432625	Average Loss: 0.7136023720062564
# Epoch 15:
# 	Train: Average Accuracy: 51.15106544901065	Average Loss: 0.9123902632396008
# 	Test: Average Accuracy: 48.138297872340424	Average Loss: 0.7012101163085422
# Epoch 16:
# 	Train: Average Accuracy: 50.83713850837138	Average Loss: 0.8546315685591062
# 	Test: Average Accuracy: 47.949911347517734	Average Loss: 0.6967426262085983
# Epoch 17:
# 	Train: Average Accuracy: 50.922754946727544	Average Loss: 0.8181433776098166
# 	Test: Average Accuracy: 49.013741134751776	Average Loss: 0.6945678957555949
# Epoch 18:
# 	Train: Average Accuracy: 50.780060882800605	Average Loss: 0.7941520301014628
# 	Test: Average Accuracy: 51.163563829787236	Average Loss: 0.6936611552663883
# Epoch 19:
# 	Train: Average Accuracy: 50.780060882800605	Average Loss: 0.7769052423198078
# 	Test: Average Accuracy: 51.2854609929078	Average Loss: 0.6935359491677785
# Epoch 20:
# 	Train: Average Accuracy: 50.75152207001521	Average Loss: 0.7642420458450498
# 	Test: Average Accuracy: 51.45168439716312	Average Loss: 0.6938690131583519
# Epoch 21:
# 	Train: Average Accuracy: 50.66590563165905	Average Loss: 0.7547811523212693
# 	Test: Average Accuracy: 51.81737588652482	Average Loss: 0.6944577313793286
# Epoch 22:
# 	Train: Average Accuracy: 50.83713850837138	Average Loss: 0.7475454560843894
# 	Test: Average Accuracy: 51.98359929078014	Average Loss: 0.6951799935625257
# Epoch 23:
# 	Train: Average Accuracy: 50.66590563165905	Average Loss: 0.7418672767246425
# 	Test: Average Accuracy: 51.71764184397163	Average Loss: 0.6959617582255081
# Epoch 24:
# 	Train: Average Accuracy: 50.56601978691019	Average Loss: 0.737298653859073
# 	Test: Average Accuracy: 51.850620567375884	Average Loss: 0.6967569365318838
# Epoch 25:
# 	Train: Average Accuracy: 50.43759512937594	Average Loss: 0.7335382599867553
# 	Test: Average Accuracy: 51.95035460992907	Average Loss: 0.6975361785180462

# %% [markdown]
# با کاهش لرنینگ ریت دقت کمتر شد و لاس بهبودی نیافت زیرا سرعت یادگیری افت میکند.
# با این حساب بهترین لرنینگ ریت همان 0.001 است.

# %% [markdown]
# قسمت چهارم. تاثیر اکتیویشن فانکشن

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=Sigmoid(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 51.407914764079145	Average Loss: 1.2327070833891471
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037891950480863
# Epoch 2:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233269345171558
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037891606877237
# Epoch 3:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332692828590395
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037891263614543
# Epoch 4:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233269220310372
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037890920692161
# Epoch 5:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332691575267656
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037890578109465
# Epoch 6:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332690945094178
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037890235865835
# Epoch 7:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332690312595316
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037889893960656
# Epoch 8:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332689677783026
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037889552393304
# Epoch 9:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332689040669198
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037889211163165
# Epoch 10:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233268840126579
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037888870269626
# Epoch 11:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332687759584589
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037888529712069
# Epoch 12:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.23326871156375
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037888189489879
# Epoch 13:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233268646943621
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037887849602451
# Epoch 14:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.23326858209925
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037887510049167
# Epoch 15:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233268517031811
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.703788717082942
# Epoch 16:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332684517424666
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037886831942602
# Epoch 17:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233268386232385
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.703788649338811
# Epoch 18:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332683205027195
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037886155165333
# Epoch 19:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332682545546358
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037885817273667
# Epoch 20:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332681883892807
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037885479712509
# Epoch 21:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332681220078021
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037885142481262
# Epoch 22:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332680554113546
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037884805579316
# Epoch 23:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332679886010738
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037884469006077
# Epoch 24:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2332679215780982
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037884132760949
# Epoch 25:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233267854343566
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.703788379684333

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=Tanh(), weight_initializer='normal')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 50.89421613394216	Average Loss: 1.2677679164236373
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905649028744
# Epoch 2:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334764427215006
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905535690592
# Epoch 3:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334764773801132
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905422330004
# Epoch 4:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233476512053466
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905308946891
# Epoch 5:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233476546741615
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905195541176
# Epoch 6:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334765814446018
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037905082112768
# Epoch 7:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334766161625028
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904968661591
# Epoch 8:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334766508953412
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904855187557
# Epoch 9:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334766856431865
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904741690582
# Epoch 10:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334767204060877
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904628170583
# Epoch 11:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334767551840884
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904514627477
# Epoch 12:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334767899772519
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904401061178
# Epoch 13:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334768247856254
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904287471606
# Epoch 14:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334768596092627
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904173858673
# Epoch 15:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.23347689444821
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037904060222298
# Epoch 16:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334769293025232
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903946562396
# Epoch 17:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334769641722672
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903832878881
# Epoch 18:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334769990574725
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.703790371917167
# Epoch 19:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334770339582135
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903605440679
# Epoch 20:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334770688745254
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903491685827
# Epoch 21:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.233477103806473
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903377907025
# Epoch 22:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334771387540957
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903264104193
# Epoch 23:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334771737174561
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903150277237
# Epoch 24:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334772086966086
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037903036426086
# Epoch 25:
# 	Train: Average Accuracy: 51.35083713850837	Average Loss: 1.2334772436916068
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7037902922550647

# %% [markdown]
#  این توابع به مقادیر بسیار کم یا بسیار زیادی ورودی واکنش درخوری نشان نمیدهد و شیب را از بین میبرد
#
#  که به این مساله
#
#  vanishing gradient
#
#  نیز گفته می شود.

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 32)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 32)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=LeakyRelu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in multiply
#   del sys.path[0]
# 	Train: Average Accuracy: 50.26636225266362	Average Loss: nan
# 	Test: Average Accuracy: 51.75088652482269	Average Loss: 0.7001748680778034
# Epoch 2:
# 	Train: Average Accuracy: 50.48040334855403	Average Loss: 0.6962670922545975
# 	Test: Average Accuracy: 51.684397163120565	Average Loss: 0.6945881198701939
# Epoch 3:
# 	Train: Average Accuracy: 50.932267884322684	Average Loss: 0.6939118989251211
# 	Test: Average Accuracy: 51.4738475177305	Average Loss: 0.6934028408998376
# Epoch 4:
# 	Train: Average Accuracy: 51.560121765601224	Average Loss: 0.6930342492318414
# 	Test: Average Accuracy: 51.329787234042556	Average Loss: 0.6932179340423938
# Epoch 5:
# 	Train: Average Accuracy: 52.202245053272456	Average Loss: 0.6925294340503956
# 	Test: Average Accuracy: 51.36303191489362	Average Loss: 0.6932525480078378
# Epoch 6:
# 	Train: Average Accuracy: 52.416286149162865	Average Loss: 0.6921545006156639
# 	Test: Average Accuracy: 51.72872340425532	Average Loss: 0.6934410020010229
# Epoch 7:
# 	Train: Average Accuracy: 52.71594368340944	Average Loss: 0.691799319614088
# 	Test: Average Accuracy: 51.70656028368795	Average Loss: 0.6936502108166931
# Epoch 8:
# 	Train: Average Accuracy: 52.78729071537291	Average Loss: 0.6914183329712988
# 	Test: Average Accuracy: 51.606826241134755	Average Loss: 0.6939873520154352
# Epoch 9:
# 	Train: Average Accuracy: 52.88717656012177	Average Loss: 0.6910578538973046
# 	Test: Average Accuracy: 51.73980496453901	Average Loss: 0.6942279912009938
# Epoch 10:
# 	Train: Average Accuracy: 53.129756468797574	Average Loss: 0.6906493630441878
# 	Test: Average Accuracy: 51.54033687943263	Average Loss: 0.6945967877737209
# Epoch 11:
# 	Train: Average Accuracy: 53.25818112633182	Average Loss: 0.6902317516200778
# 	Test: Average Accuracy: 51.54033687943263	Average Loss: 0.694948243778725
# Epoch 12:
# 	Train: Average Accuracy: 53.40087519025876	Average Loss: 0.6899189086226635
# 	Test: Average Accuracy: 51.54033687943263	Average Loss: 0.6952499274526259
# Epoch 13:
# 	Train: Average Accuracy: 53.32952815829529	Average Loss: 0.6894040745132116
# 	Test: Average Accuracy: 51.70656028368795	Average Loss: 0.6959276983168018
# Epoch 14:
# 	Train: Average Accuracy: 53.757610350076106	Average Loss: 0.688892580939034
# 	Test: Average Accuracy: 51.52925531914894	Average Loss: 0.6964284970794419
# Epoch 15:
# 	Train: Average Accuracy: 54.071537290715376	Average Loss: 0.6884055471981754
# 	Test: Average Accuracy: 51.73980496453901	Average Loss: 0.6970062201600037
# Epoch 16:
# 	Train: Average Accuracy: 54.385464231354646	Average Loss: 0.6877994061007293
# 	Test: Average Accuracy: 51.67331560283688	Average Loss: 0.697669009759037
# Epoch 17:
# 	Train: Average Accuracy: 54.66133942161339	Average Loss: 0.6872479187571788
# 	Test: Average Accuracy: 51.828457446808514	Average Loss: 0.6987463608072292
# Epoch 18:
# 	Train: Average Accuracy: 55.146499238964985	Average Loss: 0.6865486826402619
# 	Test: Average Accuracy: 51.76196808510638	Average Loss: 0.6993669274831142
# Epoch 19:
# 	Train: Average Accuracy: 55.24638508371385	Average Loss: 0.685900517243091
# 	Test: Average Accuracy: 51.684397163120565	Average Loss: 0.7005643001895347
# Epoch 20:
# 	Train: Average Accuracy: 55.631659056316586	Average Loss: 0.6851410495645197
# 	Test: Average Accuracy: 51.78413120567375	Average Loss: 0.7019823466257514
# Epoch 21:
# 	Train: Average Accuracy: 55.80289193302892	Average Loss: 0.6844998719808548
# 	Test: Average Accuracy: 51.61790780141844	Average Loss: 0.7023928947386208
# Epoch 22:
# 	Train: Average Accuracy: 55.87423896499239	Average Loss: 0.6836592414793902
# 	Test: Average Accuracy: 51.61790780141844	Average Loss: 0.7036020100154314
# Epoch 23:
# 	Train: Average Accuracy: 55.917047184170464	Average Loss: 0.6826737051185007
# 	Test: Average Accuracy: 51.518173758865245	Average Loss: 0.7047157781565824
# Epoch 24:
# 	Train: Average Accuracy: 56.159627092846264	Average Loss: 0.6818480199540743
# 	Test: Average Accuracy: 51.518173758865245	Average Loss: 0.7059946030957692
# Epoch 25:
# 	Train: Average Accuracy: 56.45928462709284	Average Loss: 0.6809748724370539
# 	Test: Average Accuracy: 51.48492907801418	Average Loss: 0.706721998686557

# %% [markdown]
# چون این تابع برای مقادیر منفی  شیب کوچکی دارد به هنگام بک پروپگیت یادگیری انجام میشود.

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 16)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 16)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=LeakyRelu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in multiply
#   del sys.path[0]
# 	Train: Average Accuracy: 50.52796803652968	Average Loss: nan
# 	Test: Average Accuracy: 51.795212765957444	Average Loss: 0.7038060611527935
# Epoch 2:
# 	Train: Average Accuracy: 50.94178082191781	Average Loss: 0.7002131976637403
# 	Test: Average Accuracy: 51.795212765957444	Average Loss: 0.6990974113037585
# Epoch 3:
# 	Train: Average Accuracy: 51.08447488584475	Average Loss: 0.6952150259027623
# 	Test: Average Accuracy: 51.69547872340426	Average Loss: 0.6951615008265325
# Epoch 4:
# 	Train: Average Accuracy: 51.09874429223744	Average Loss: 0.6936331437065485
# 	Test: Average Accuracy: 51.828457446808514	Average Loss: 0.693785455482477
# Epoch 5:
# 	Train: Average Accuracy: 51.55536529680365	Average Loss: 0.6929019800236341
# 	Test: Average Accuracy: 51.795212765957444	Average Loss: 0.6934145620972518
# Epoch 6:
# 	Train: Average Accuracy: 51.72659817351598	Average Loss: 0.692402572127422
# 	Test: Average Accuracy: 51.994680851063826	Average Loss: 0.6934668908495198
# Epoch 7:
# 	Train: Average Accuracy: 52.04052511415525	Average Loss: 0.6919955730399904
# 	Test: Average Accuracy: 51.994680851063826	Average Loss: 0.6936216366381119
# Epoch 8:
# 	Train: Average Accuracy: 52.42579908675799	Average Loss: 0.6916088322575372
# 	Test: Average Accuracy: 51.52925531914894	Average Loss: 0.6938415521614064
# Epoch 9:
# 	Train: Average Accuracy: 52.59703196347032	Average Loss: 0.6912313848459084
# 	Test: Average Accuracy: 52.12765957446808	Average Loss: 0.6941130857540089
# Epoch 10:
# 	Train: Average Accuracy: 52.75399543378995	Average Loss: 0.690860428057418
# 	Test: Average Accuracy: 52.027925531914896	Average Loss: 0.6943130667137878
# Epoch 11:
# 	Train: Average Accuracy: 53.167808219178085	Average Loss: 0.6904512343278232
# 	Test: Average Accuracy: 52.160904255319146	Average Loss: 0.6946664333944935
# Epoch 12:
# 	Train: Average Accuracy: 53.29623287671233	Average Loss: 0.6900037913757217
# 	Test: Average Accuracy: 51.9281914893617	Average Loss: 0.6950453160701984
# Epoch 13:
# 	Train: Average Accuracy: 53.538812785388124	Average Loss: 0.6895604541999443
# 	Test: Average Accuracy: 51.89494680851064	Average Loss: 0.6955872731057984
# Epoch 14:
# 	Train: Average Accuracy: 53.75285388127854	Average Loss: 0.6890249269914335
# 	Test: Average Accuracy: 51.994680851063826	Average Loss: 0.6960336698759545
# Epoch 15:
# 	Train: Average Accuracy: 53.92408675799087	Average Loss: 0.6885253695939177
# 	Test: Average Accuracy: 52.12765957446808	Average Loss: 0.6966275127273124
# Epoch 16:
# 	Train: Average Accuracy: 54.29509132420091	Average Loss: 0.687885253832611
# 	Test: Average Accuracy: 52.194148936170215	Average Loss: 0.6966376692676508
# Epoch 17:
# 	Train: Average Accuracy: 54.3236301369863	Average Loss: 0.6872933751620675
# 	Test: Average Accuracy: 51.861702127659576	Average Loss: 0.6976537966643113
# Epoch 18:
# 	Train: Average Accuracy: 54.92294520547945	Average Loss: 0.68648864653602
# 	Test: Average Accuracy: 51.961436170212764	Average Loss: 0.6979927966597992
# Epoch 19:
# 	Train: Average Accuracy: 55.279680365296805	Average Loss: 0.6856589162291412
# 	Test: Average Accuracy: 51.994680851063826	Average Loss: 0.6987616190012039
# Epoch 20:
# 	Train: Average Accuracy: 55.46518264840183	Average Loss: 0.6847286103081937
# 	Test: Average Accuracy: 52.09441489361702	Average Loss: 0.6994207273700113
# Epoch 21:
# 	Train: Average Accuracy: 55.45091324200913	Average Loss: 0.6839631393565135
# 	Test: Average Accuracy: 51.76196808510638	Average Loss: 0.6998452343669909
# Epoch 22:
# 	Train: Average Accuracy: 55.821917808219176	Average Loss: 0.6830913537371511
# 	Test: Average Accuracy: 51.795212765957444	Average Loss: 0.7006755899202922
# Epoch 23:
# 	Train: Average Accuracy: 55.92180365296804	Average Loss: 0.6820449218911837
# 	Test: Average Accuracy: 51.69547872340426	Average Loss: 0.7021675285759229
# Epoch 24:
# 	Train: Average Accuracy: 56.17865296803653	Average Loss: 0.6809874240199563
# 	Test: Average Accuracy: 51.52925531914894	Average Loss: 0.7031109878051932
# Epoch 25:
# 	Train: Average Accuracy: 56.207191780821915	Average Loss: 0.6797481703224071
# 	Test: Average Accuracy: 51.662234042553195	Average Loss: 0.7044219266853242

# %%
INPUT_SHAPE = 1024
LEARNING_RATE = 0.001
EPOCHS = 25
TRAINLOADER = Dataloader(X_train, y_train, n_classes = 2, batch_size = 256)
TESTLOADER = Dataloader(X_test, y_test, n_classes = 2, batch_size = 256)

network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(200, input_shape=INPUT_SHAPE, activation=LeakyRelu(), weight_initializer='uniform')
network.add_layer(2, activation=Identical(), weight_initializer='uniform')
network.set_training_param(loss=CrossEntropy(), lr=LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER, True)
# Out:
# Epoch 1:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in multiply
#   del sys.path[0]
# 	Train: Average Accuracy: 49.24031047077922	Average Loss: nan
# 	Test: Average Accuracy: 48.2804008152174	Average Loss: 12.085565266894507
# Epoch 2:
# 	Train: Average Accuracy: 50.09004667207792	Average Loss: 28.57715244195313
# 	Test: Average Accuracy: 51.7195991847826	Average Loss: 0.8071812773013868
# Epoch 3:
# 	Train: Average Accuracy: 51.26192167207792	Average Loss: 3.6408591269460877
# 	Test: Average Accuracy: 48.24784873188406	Average Loss: 0.7885425902731042
# Epoch 4:
# 	Train: Average Accuracy: 48.20667613636363	Average Loss: 0.8950136675003326
# 	Test: Average Accuracy: 51.7195991847826	Average Loss: 0.6928317627834278
# Epoch 5:
# 	Train: Average Accuracy: 48.639153814935064	Average Loss: 0.713462746088967
# 	Test: Average Accuracy: 48.312952898550726	Average Loss: 0.6934014427556631
# Epoch 6:
# 	Train: Average Accuracy: 48.443841314935064	Average Loss: 0.7069699644607157
# 	Test: Average Accuracy: 48.2804008152174	Average Loss: 0.6936263059663249
# Epoch 7:
# 	Train: Average Accuracy: 48.80656452922078	Average Loss: 0.7039334705287389
# 	Test: Average Accuracy: 48.27332427536232	Average Loss: 0.6937260845886656
# Epoch 8:
# 	Train: Average Accuracy: 48.51359577922078	Average Loss: 0.7021083923262635
# 	Test: Average Accuracy: 48.05819746376812	Average Loss: 0.693772091777923
# Epoch 9:
# 	Train: Average Accuracy: 48.6531047077922	Average Loss: 0.7008661569723087
# 	Test: Average Accuracy: 48.38937952898551	Average Loss: 0.6937897082226999
# Epoch 10:
# 	Train: Average Accuracy: 48.49964488636363	Average Loss: 0.6999535489164842
# 	Test: Average Accuracy: 48.89039855072463	Average Loss: 0.6937898379580117
# Epoch 11:
# 	Train: Average Accuracy: 48.51359577922078	Average Loss: 0.6992472338158912
# 	Test: Average Accuracy: 49.17062952898551	Average Loss: 0.6937790731660227
# Epoch 12:
# 	Train: Average Accuracy: 48.80656452922078	Average Loss: 0.6986797388152521
# 	Test: Average Accuracy: 49.58673007246377	Average Loss: 0.6937612841188597
# Epoch 13:
# 	Train: Average Accuracy: 49.18323863636363	Average Loss: 0.6982097240112136
# 	Test: Average Accuracy: 49.88677536231884	Average Loss: 0.6937382295247652
# Epoch 14:
# 	Train: Average Accuracy: 49.0437297077922	Average Loss: 0.6978124840347737
# 	Test: Average Accuracy: 49.796195652173914	Average Loss: 0.6937131448867683
# Epoch 15:
# 	Train: Average Accuracy: 49.0437297077922	Average Loss: 0.6974725326118555
# 	Test: Average Accuracy: 49.946218297101446	Average Loss: 0.6936873643393637
# Epoch 16:
# 	Train: Average Accuracy: 49.05768060064935	Average Loss: 0.6971758228326298
# 	Test: Average Accuracy: 49.52304121376812	Average Loss: 0.6936611508028446
# Epoch 17:
# 	Train: Average Accuracy: 49.0437297077922	Average Loss: 0.696913889698613
# 	Test: Average Accuracy: 49.58106884057971	Average Loss: 0.6936350369647514
# Epoch 18:
# 	Train: Average Accuracy: 49.01582792207792	Average Loss: 0.696681422439883
# 	Test: Average Accuracy: 49.470674818840585	Average Loss: 0.6936093420895695
# Epoch 19:
# 	Train: Average Accuracy: 49.21114042207792	Average Loss: 0.696471874428909
# 	Test: Average Accuracy: 49.796195652173914	Average Loss: 0.6935847810532044
# Epoch 20:
# 	Train: Average Accuracy: 49.40645292207792	Average Loss: 0.6962839434367194
# 	Test: Average Accuracy: 49.83582427536232	Average Loss: 0.69356134341536
# Epoch 21:
# 	Train: Average Accuracy: 49.462256493506494	Average Loss: 0.6961131687976295
# 	Test: Average Accuracy: 49.777796648550726	Average Loss: 0.6935393238664519
# Epoch 22:
# 	Train: Average Accuracy: 49.4343547077922	Average Loss: 0.6959570804739331
# 	Test: Average Accuracy: 50.01839900362319	Average Loss: 0.6935192727577247
# Epoch 23:
# 	Train: Average Accuracy: 49.39250202922078	Average Loss: 0.6958138243260005
# 	Test: Average Accuracy: 49.960371376811594	Average Loss: 0.6934997773641224
# Epoch 24:
# 	Train: Average Accuracy: 49.420403814935064	Average Loss: 0.6956816484724992
# 	Test: Average Accuracy: 49.960371376811594	Average Loss: 0.6934842238762436
# Epoch 25:
# 	Train: Average Accuracy: 49.40645292207792	Average Loss: 0.6955601663862997
# 	Test: Average Accuracy: 50.01273777173913	Average Loss: 0.6934719748606795

# %% [markdown]
# batch_size 32
#
# از همه بهتر است.چون همگرایی سریع تری رقم میزند.
#
# اگر خیلی کوچک در نظر بگیریم اصلا بهینه نیست ویادگیری خیلی کند میشود.
